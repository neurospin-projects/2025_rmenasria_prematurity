# %%
import os
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
from sklearn.model_selection import (
    KFold,
    GridSearchCV,
    cross_val_score,
    cross_val_predict
)

# %%
def get_region_list(base_path):
    return sorted([
        d for d in os.listdir(base_path)
        if os.path.isdir(os.path.join(base_path, d))
           and not d.startswith('all_models')
           and not d.startswith('hcp')
           and not d.startswith('ukb')
           and not d.endswith('.csv')
           and not d.endswith('.sh')
           and not d.endswith('embeddings')
    ])

# %%
# CONFIG
labels_path = "/neurospin/dico/rmenasria/Runs/03_main/Input/cognition/nc_y_nihtb.csv"
base_path   = "/neurospin/dico/data/deep_folding/current/models/Champollion_V1_after_ablation/embeddings/ABCD_embeddings/"

scores = [
 'nihtbx_flanker_agecorrected',
 'nihtbx_cardsort_agecorrected',
 'nihtbx_list_agecorrected',
 'nihtbx_pattern_agecorrected',
 'nihtbx_picvocab_agecorrected',
 'nihtbx_reading_agecorrected',
 'nihtbx_fluidcomp_agecorrected',
 'nihtbx_cryst_agecorrected',
 'nihtbx_totalcomp_agecorrected'
]

labels_df = pd.read_csv(labels_path)
#print(labels_df.shape)
labels_df = labels_df[labels_df["eventname"] == "baseline_year_1_arm_1"]
#print(labels_df.shape)

existing_scores = [s for s in scores if s in labels_df.columns]
cols = ["src_subject_id"] + existing_scores
labels_df = labels_df[cols]
#print(labels_df.index)

regions = get_region_list(os.path.join(base_path,"../.."))
regions.remove("params_OLS")
regions.remove("region_list")
regions.remove("analysis")
#regions = ["STs_right","FCLp-subsc-FCLa-INSULA_right","FCMpost-SpC_right","STi-STs-STpol_right"]
#region = regions[0]

labels_df['src_subject_id'] = (
    labels_df['src_subject_id'].astype(str)
    .str.replace(r"^sub-", "", regex=True)
    .str.replace("_", "", regex=False)
)

df_ages = pd.read_csv("/neurospin/dico/rmenasria/Runs/03_main/Input/ABCD/prematurity_labels_true_classes.csv")
# Out:
# /tmp/ipykernel_1377999/1813368158.py:17: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   labels_df = pd.read_csv(labels_path)

# %%
def load_embeddings(region):
    
    for file in os.listdir(base_path):
            if file.startswith(region) and file.endswith(".csv"):
                embedding_file = file
                break
            
    if embedding_file is None:
        raise FileNotFoundError(f"No embedding file found for region: {region}")

    #print(f"Using embedding file: {embedding_file}")

    emb_path = os.path.join(base_path, embedding_file)
    emb_df = pd.read_csv(emb_path)
    emb_df['ID_clean'] = (
        emb_df['ID'].astype(str)
        .str.replace(r"^sub-", "", regex=True)
        .str.replace("_", "", regex=False)
    )
    return emb_df

# %%
def preprocess_data(df,prem_class,score):
    
    df_with_cognition = df.merge(
        labels_df,
        left_on='ID_clean', right_on='src_subject_id', how='inner'
    )
    df_with_cognition_and_ages= df_with_cognition.merge(df_ages, left_on='src_subject_id', right_on='src_subject_id', how='inner')
    df_with_cognition_and_ages= df_with_cognition_and_ages[df_with_cognition_and_ages["prem_class"].isin(prem_class)]

    df_with_cognition_and_ages['y'] = df_with_cognition_and_ages[score]
    df_with_cognition_and_ages.dropna(subset=[score], inplace=True)

    X = df_with_cognition_and_ages.filter(regex=r'^dim').values
    y = df_with_cognition_and_ages['y'].values

    return X, y

# %%
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

def regress_on_cognition_bootstrap(score, region, prem_class, n_boot=750, random_state=42):
    rng = np.random.default_rng(random_state)

    emb_df = load_embeddings(region)
    X, y = preprocess_data(emb_df, prem_class, score)
    n = len(y)

    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('regressor', Ridge())
    ])

    grid = GridSearchCV(
        pipe, {'regressor__alpha': [0.01, 0.1, 1, 10]},
        cv=5, scoring='r2', n_jobs=-1
    )

    r2_list = []

    for i in range(n_boot):
        # Tirage bootstrap avec remise
        idx_boot = rng.integers(0, n, size=n)
        X_boot, y_boot = X[idx_boot], y[idx_boot]

        # Indices OOB
        oob_mask = np.ones(n, dtype=bool)
        oob_mask[np.unique(idx_boot)] = False
        oob_idx = np.where(oob_mask)[0]

        # Fit modèle (avec GridSearch)
        grid.fit(X_boot, y_boot)

        if len(oob_idx) > 0:
            # Évalue sur OOB
            y_oob_pred = grid.predict(X[oob_idx])
            r2 = r2_score(y[oob_idx], y_oob_pred)

        else:
            # Rare: pas d'OOB, fallback = NaN
            r2 = np.nan

        r2_list.append(r2)

    r2_arr = np.array(r2_list)

    results = {
        "region": region,
        "score": score,
        "n": n,
        "r2_mean": np.nanmean(r2_arr),
        "r2_ci": np.nanpercentile(r2_arr, [2.5, 97.5]),
    }

    print(f"Bootstrap results for {region}, {score}:")
    print("R² mean:", results["r2_mean"], "95% CI:", results["r2_ci"])

    return results

# %%
print(regions)
to_remove = ["FIP-FIPPoCinf_left","FIP-FIPPoCinf_right",
             "SCall_left","SCall_right",
             "SCall-SsP-SintraCing_right","SCall-SsP-SintraCing_left"]

# Version compréhension de liste
regions = [r for r in regions if r not in to_remove]

# ou version boucle
for r in to_remove:
    if r in regions:
        regions.remove(r)

print(len(regions))

results = []
out_path = "/neurospin/dico/rmenasria/Runs/03_main/Output/csv/cognitive/r2boostrap_prema_all_regions.csv"
for region in regions:
    for score in scores:
        result = regress_on_cognition_bootstrap(score, region,["28-32","32-37"])
        results.append(result)

results_df = pd.DataFrame(results)
results_df.to_csv(out_path, index=False)


results_terms= []
out_path = "/neurospin/dico/rmenasria/Runs/03_main/Output/csv/cognitive/r2boostrap_terms_all_regions.csv"
for region in regions:
    for score in scores:
        result = regress_on_cognition_bootstrap(score, region,[">=37"])
        results_terms.append(result)

results_df_terms = pd.DataFrame(results_terms)
results_df_terms.to_csv(out_path, index=False)


results_extr_prem= []
out_path = "/neurospin/dico/rmenasria/Runs/03_main/Output/csv/cognitive/r2boostrap_extrprema_all_regions.csv"
for region in regions:
    for score in scores:
        result = regress_on_cognition_bootstrap(score, region,["<28"])
        results_extr_prem.append(result)

results_df_extr_prem = pd.DataFrame(results_extr_prem)
results_df_extr_prem.to_csv(out_path, index=False)
# Out:
# ['CINGULATE_left', 'CINGULATE_right', 'FCLp-subsc-FCLa-INSULA_left', 'FCLp-subsc-FCLa-INSULA_right', 'FCMpost-SpC_left', 'FCMpost-SpC_right', 'FColl-SRh_left', 'FColl-SRh_right', 'FIP_left', 'FIP_right', 'FPO-SCu-ScCal_left', 'FPO-SCu-ScCal_right', 'LARGE_CINGULATE_left', 'LARGE_CINGULATE_right', 'Lobule_parietal_sup_left', 'Lobule_parietal_sup_right', 'OCCIPITAL_left', 'OCCIPITAL_right', 'SC-SPeC_left', 'SC-SPeC_right', 'SC-SPoC_left', 'SC-SPoC_right', 'SC-sylv_left', 'SC-sylv_right', 'SFinf-BROCA-SPeCinf_left', 'SFinf-BROCA-SPeCinf_right', 'SFint-FCMant_left', 'SFint-FCMant_right', 'SFint-SR_left', 'SFint-SR_right', 'SFinter-SFsup_left', 'SFinter-SFsup_right', 'SFmarginal-SFinfant_left', 'SFmarginal-SFinfant_right', 'SFmedian-SFpoltr-SFsup_left', 'SFmedian-SFpoltr-SFsup_right', 'SOr-SOlf_left', 'SOr-SOlf_right', 'SOr_left', 'SOr_right', 'SPeC_left', 'SPeC_right', 'SPoC_left', 'SPoC_right', 'STi-SOTlat_left', 'STi-SOTlat_right', 'STi-STs-STpol_left', 'STi-STs-STpol_right', 'STs_left', 'STs_right', 'STsbr_left', 'STsbr_right', 'ScCal-SLi_left', 'ScCal-SLi_right', 'SsP-SPaint_left', 'SsP-SPaint_right', 'fronto-parietal_medial_face_left', 'fronto-parietal_medial_face_right']
# 58
# Bootstrap results for CINGULATE_left, nihtbx_flanker_agecorrected:
# R² mean: -0.039971680328528415 95% CI: [-0.09328681  0.00334218]
# Bootstrap results for CINGULATE_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.0442412301291159 95% CI: [-0.09942781 -0.00317962]
# Bootstrap results for CINGULATE_left, nihtbx_list_agecorrected:
# R² mean: -0.02656788994804983 95% CI: [-0.07961036  0.01388671]
# Bootstrap results for CINGULATE_left, nihtbx_pattern_agecorrected:
# R² mean: -0.04626224178976734 95% CI: [-0.09383444 -0.00350786]
# Bootstrap results for CINGULATE_left, nihtbx_picvocab_agecorrected:
# R² mean: -0.03213458444230024 95% CI: [-0.08341619  0.01146569]
# Bootstrap results for CINGULATE_left, nihtbx_reading_agecorrected:
# R² mean: -0.052549519338584504 95% CI: [-0.10480234 -0.01278338]
# Bootstrap results for CINGULATE_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.040300606217813416 95% CI: [-0.10166791  0.0024865 ]
# Bootstrap results for CINGULATE_left, nihtbx_cryst_agecorrected:
# R² mean: -0.04087137400215797 95% CI: [-0.08881538  0.00056639]
# Bootstrap results for CINGULATE_left, nihtbx_totalcomp_agecorrected:
# R² mean: -0.03829975013894683 95% CI: [-0.09729206  0.00489534]
# Bootstrap results for CINGULATE_right, nihtbx_flanker_agecorrected:
# R² mean: -0.04720970702848266 95% CI: [-0.09801887 -0.0108693 ]
# Bootstrap results for CINGULATE_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.04882853271217008 95% CI: [-0.10281907 -0.00984257]
# Bootstrap results for CINGULATE_right, nihtbx_list_agecorrected:
# R² mean: -0.04377667485016899 95% CI: [-0.0975952  -0.00250925]
# Bootstrap results for CINGULATE_right, nihtbx_pattern_agecorrected:
# R² mean: -0.04373645193498879 95% CI: [-0.09716269 -0.00433569]
# Bootstrap results for CINGULATE_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.031222152453976974 95% CI: [-0.08419274  0.01135714]
# Bootstrap results for CINGULATE_right, nihtbx_reading_agecorrected:
# R² mean: -0.03659740006062934 95% CI: [-0.09265955  0.00595652]
# Bootstrap results for CINGULATE_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0
right, nihtbx_picvocab_agecorrected:
# R² mean: -0.016331086155702557 95% CI: [-0.07349838  0.022934  ]
# Bootstrap results for FCMpost-SpC_right, nihtbx_reading_agecorrected:
# R² mean: -0.04522742026113389 95% CI: [-0.10078302 -0.00885217]
# Bootstrap results for FCMpost-SpC_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.025305070358656524 95% CI: [-0.08358695  0.01504792]
# Bootstrap results for FCMpost-SpC_right, nihtbx_cryst_agecorrected:
# R² mean: -0.03410513224069212 95% CI: [-0.08078149  0.00780904]
# Bootstrap results for FCMpost-SpC_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.02360392435001831 95% CI: [-0.07875061  0.0185942 ]
# Bootstrap results for FColl-SRh_left, nihtbx_flanker_agecorrected:
# R² mean: -0.034782433429600246 95% CI: [-0.08101917  0.00071388]
# Bootstrap results for FColl-SRh_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.03518429182056563 95% CI: [-0.08654864  0.0017512 ]
# Bootstrap results for FColl-SRh_left, nihtbx_list_agecorrected:
# R² mean: -0.024691821841393305 95% CI: [-0.06726527  0.0139347 ]
# Bootstrap results for FColl-SRh_left, nihtbx_pattern_agecorrected:
# R² mean: -0.032500797397788994 95% CI: [-0.08854108  0.00381841]
# Bootstrap results for FColl-SRh_left, nihtbx_picvocab_agecorrected:
# R² mean: 0.0016719551249961243 95% CI: [-0.05341658  0.04182114]
# Bootstrap results for FColl-SRh_left, nihtbx_reading_agecorrected:
# R² mean: -0.02690235381099823 95% CI: [-0.07520352  0.01107407]
# Bootstrap results for FColl-SRh_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.020730563761047392 95% CI: [-0.07132582  0.0189071 ]
# Bootstrap results for FColl-SRh_left, nihtbx_cryst_agecorrected:
# R² mean: -0.0029170062462456404 95% CI: [-0.06374633  0.04224477]
# Bootstrap results for FColl-SRh_left, nihtbx_totalcomp_agecorrected:
# R² mean: -0.008528837514544602 95% CI: [-0.06510852  0.03465632]
# Bootstrap results for FColl-SRh_right, nihtbx_flanker_agecorrected:
# R² mean: -0.025659573699208287 95% CI: [-0.07529204  0.01028881]
# Bootstrap results for FColl-SRh_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.034537607266133655 95% CI: [-0.08798394  0.00228638]
# Bootstrap results for FColl-SRh_right, nihtbx_list_agecorrected:
# R² mean: -0.03254910233092382 95% CI: [-0.08238361  0.00577758]
# Bootstrap results for FColl-SRh_right, nihtbx_pattern_agecorrected:
# R² mean: -0.03977242997316385 95% CI: [-0.08909344 -0.0002095 ]
# Bootstrap results for FColl-SRh_right, nihtbx_picvocab_agecorrected:
# R² mean: 0.003630588134704052 95% CI: [-0.06237319  0.04791579]
# Bootstrap results for FColl-SRh_right, nihtbx_reading_agecorrected:
# R² mean: -0.02662725632194586 95% CI: [-0.07685658  0.01234409]
# Bootstrap results for FColl-SRh_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.031731467481703586 95% CI: [-0.08462555  0.0101911 ]
# Bootstrap results for FColl-SRh_right, nihtbx_cryst_agecorrected:
# R² mean: -0.0032678992542480014 95% CI: [-0.06213828  0.03920677]
# Bootstrap results for FColl-SRh_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.01260212991592991 95% CI: [-0.07072613  0.03284961]
# Bootstrap results for FIP_left, nihtbx_flanker_agecorrected:
# R² mean: -0.02712747605768947 95% CI: [-0.07432049  0.01069532]
# Bootstrap results for FIP_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.
right, nihtbx_cardsort_agecorrected:
# R² mean: -0.017302902214605814 95% CI: [-0.06088722  0.01696231]
# Bootstrap results for SC-SPeC_right, nihtbx_list_agecorrected:
# R² mean: -0.02838987906972187 95% CI: [-0.0821473   0.00951935]
# Bootstrap results for SC-SPeC_right, nihtbx_pattern_agecorrected:
# R² mean: -0.03759666687799873 95% CI: [-0.08850709  0.00010035]
# Bootstrap results for SC-SPeC_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.008464308702169111 95% CI: [-0.06046079  0.03163449]
# Bootstrap results for SC-SPeC_right, nihtbx_reading_agecorrected:
# R² mean: -0.029272391536917932 95% CI: [-0.07631186  0.00892162]
# Bootstrap results for SC-SPeC_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.01595243905781471 95% CI: [-0.07079002  0.02388615]
# Bootstrap results for SC-SPeC_right, nihtbx_cryst_agecorrected:
# R² mean: -0.01997937735930685 95% CI: [-0.08086047  0.02224298]
# Bootstrap results for SC-SPeC_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.011600419954920957 95% CI: [-0.06776766  0.03177455]
# Bootstrap results for SC-SPoC_left, nihtbx_flanker_agecorrected:
# R² mean: -0.026698368552878538 95% CI: [-0.07910124  0.00901812]
# Bootstrap results for SC-SPoC_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.03608905513459658 95% CI: [-0.08231101 -0.00225686]
# Bootstrap results for SC-SPoC_left, nihtbx_list_agecorrected:
# R² mean: -0.04759257152847231 95% CI: [-0.10167049 -0.01318572]
# Bootstrap results for SC-SPoC_left, nihtbx_pattern_agecorrected:
# R² mean: -0.02905663661915532 95% CI: [-0.0755961   0.00415339]
# Bootstrap results for SC-SPoC_left, nihtbx_picvocab_agecorrected:
# R² mean: -0.03747985585515964 95% CI: [-0.09013844 -0.00244541]
# Bootstrap results for SC-SPoC_left, nihtbx_reading_agecorrected:
# R² mean: -0.039238783350412726 95% CI: [-0.08711562 -0.00808859]
# Bootstrap results for SC-SPoC_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.024230826180764234 95% CI: [-0.07685858  0.0153909 ]
# Bootstrap results for SC-SPoC_left, nihtbx_cryst_agecorrected:
# R² mean: -0.03764564063363387 95% CI: [-0.08430786 -0.00406202]
# Bootstrap results for SC-SPoC_left, nihtbx_totalcomp_agecorrected:
# R² mean: -0.029853886016763493 95% CI: [-0.08657416  0.00777947]
# Bootstrap results for SC-SPoC_right, nihtbx_flanker_agecorrected:
# R² mean: -0.036358286891412114 95% CI: [-0.08457087 -0.00357079]
# Bootstrap results for SC-SPoC_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.033754090676909945 95% CI: [-0.08360378  0.00418839]
# Bootstrap results for SC-SPoC_right, nihtbx_list_agecorrected:
# R² mean: -0.03329875498038887 95% CI: [-0.08726056  0.00289049]
# Bootstrap results for SC-SPoC_right, nihtbx_pattern_agecorrected:
# R² mean: -0.03520118344638507 95% CI: [-0.08311327 -0.0024372 ]
# Bootstrap results for SC-SPoC_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.030097861439003518 95% CI: [-0.08965749  0.0083663 ]
# Bootstrap results for SC-SPoC_right, nihtbx_reading_agecorrected:
# R² mean: -0.034920622928581106 95% CI: [-0.08786503  0.0014338 ]
# Bootstrap results for SC-SPoC_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.03253396600785014 95% CI: [-0.08779738  0.00337248]
# Bootstrap results for SC-SPoC_right, nihtbx_cryst_agecorrected:
# R² mean: -0.031086538056627224 95% CI: [-0.08773093  0.00967839]
# Bootstrap results for SC-SPoC_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.028763689301361178 95% CI: [-0.0851372   0.01129588]
# Bootstrap results for SC-sylv_left, nihtbx_flanker_agecorrected:
# R² mean: -0.029059836142701627 95% CI: [-0.07889753  0.00895049]
# Bootstrap results for SC-sylv_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.

# Bootstrap results for SFinf-BROCA-SPeCinf_right, nihtbx_cryst_agecorrected:
# R² mean: -0.008780351561826433 95% CI: [-0.06183641  0.03052294]
# Bootstrap results for SFinf-BROCA-SPeCinf_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.024542945879446037 95% CI: [-0.07425394  0.01441493]
# Bootstrap results for SFint-FCMant_left, nihtbx_flanker_agecorrected:
# R² mean: -0.04102142328327828 95% CI: [-0.09194522  0.0011994 ]
# Bootstrap results for SFint-FCMant_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.04586488224773554 95% CI: [-0.09764368 -0.00673833]
# Bootstrap results for SFint-FCMant_left, nihtbx_list_agecorrected:
# R² mean: -0.02705873699672546 95% CI: [-0.07707863  0.01497493]
# Bootstrap results for SFint-FCMant_left, nihtbx_pattern_agecorrected:
# R² mean: -0.05427264864954805 95% CI: [-0.1059846  -0.01536178]
# Bootstrap results for SFint-FCMant_left, nihtbx_picvocab_agecorrected:
# R² mean: -0.015100287947852032 95% CI: [-0.06964115  0.02760218]
# Bootstrap results for SFint-FCMant_left, nihtbx_reading_agecorrected:
# R² mean: -0.0418489580391302 95% CI: [-0.0984539  -0.00297332]
# Bootstrap results for SFint-FCMant_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.05123965934871571 95% CI: [-0.10286939 -0.00989363]
# Bootstrap results for SFint-FCMant_left, nihtbx_cryst_agecorrected:
# R² mean: -0.023213454304339506 95% CI: [-0.07672815  0.01729757]
# Bootstrap results for SFint-FCMant_left, nihtbx_totalcomp_agecorrected:
# R² mean: -0.034685673749667786 95% CI: [-0.09141903  0.01030667]
# Bootstrap results for SFint-FCMant_right, nihtbx_flanker_agecorrected:
# R² mean: -0.047672100737185585 95% CI: [-0.10439134 -0.00926653]
# Bootstrap results for SFint-FCMant_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.04759767774672651 95% CI: [-0.10330679 -0.00979679]
# Bootstrap results for SFint-FCMant_right, nihtbx_list_agecorrected:
# R² mean: -0.04919984192581149 95% CI: [-0.09954972 -0.01055714]
# Bootstrap results for SFint-FCMant_right, nihtbx_pattern_agecorrected:
# R² mean: -0.04075856044631503 95% CI: [-0.0963678 -0.0001745]
# Bootstrap results for SFint-FCMant_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.029301967480916482 95% CI: [-0.08192203  0.01134668]
# Bootstrap results for SFint-FCMant_right, nihtbx_reading_agecorrected:
# R² mean: -0.03873631393086788 95% CI: [-9.37497020e-02 -4.06411153e-05]
# Bootstrap results for SFint-FCMant_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.03996193074859614 95% CI: [-0.09689856  0.00285568]
# Bootstrap results for SFint-FCMant_right, nihtbx_cryst_agecorrected:
# R² mean: -0.02699541148391738 95% CI: [-0.08469031  0.01448454]
# Bootstrap results for SFint-FCMant_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.02506937200093862 95% CI: [-0.07800816  0.01982743]
# Bootstrap results for SFint-SR_left, nihtbx_flanker_agecorrected:
# R² mean: -0.03836685869138998 95% CI: [-0.08388138 -0.00113455]
# Bootstrap results for SFint-SR_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.044853057095395284 95% CI: [-0.09126226 -0.01140779]
# Bootstrap results for SFint-SR_left, nihtbx_list_agecorrected:
# R² mean: -0.03743921181279807 95% CI: [-0.08962862  0.00420619]
# Bootstrap results for SFint-SR_left, nihtbx_pattern_agecorrected:
# R² mean: -0.03971135426937679 95% CI: [-8.81295567e-02 -3.84818529e-05]
# Bootstrap results for SFint-SR_left, nihtbx_picvocab_agecorrected:
# R² mean: -0.02113351888116182 95% CI: [-0.07355641  0.01972627]
# Bootstrap results for SFint-SR_left, nihtbx_reading_agecorrected:
# R² mean: -0.04498885240310924 95% CI: [-0.10271934 -0.00347077]
# Bootstrap results for SFint-SR_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.04593923714178921 95% CI: [-0.09451781 -0.00846096]
# Bootstrap results for SFint-SR_left, nihtbx_cryst_agecorrected:
# R² mean: -0.02975351325711379 95% CI: [-0.08330556  0.01049707]
# Bootstrap results for SFint-SR_left, nihtbx_totalcomp_agecorrected:
# R² mean: -0.04018869893511995 95% CI: [-0.09590691  0.00079322]
# Bootstrap results for SFint-SR_right, nihtbx_flanker_agecorrected:
# R² mean: -0.04655592761551892 95% CI: [-0.09459396 -0.00860053]
# Bootstrap results for SFint-SR_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.04840431319603085 95% CI: [-0.09828703 -0.01350698]
# Bootstrap results for SFint-SR_right, nihtbx_list_agecorrected:
# R² mean: -0.04616320765762659 95% CI: [-0.09717184 -0.00779802]
# Bootstrap results for SFint-SR_right, nihtbx_pattern_agecorrected:
# R² mean: -0.04154502710319245 95% CI: [-0.09104791  0.00014541]
# Bootstrap results for SFint-SR_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.03957867724475514 95% CI: [-0.09111362  0.00058656]
# Bootstrap results for SFint-SR_right, nihtbx_reading_agecorrected:
# R² mean: -0.044535031730084315 95% CI: [-0.10094957 -0.00169359]
# Bootstrap results for SFint-SR_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.03564279793860692 95% CI: [-0.08821394  0.00551759]
# Bootstrap results for SFint-SR_right, nihtbx_cryst_agecorrected:
# R² mean: -0.03379344483168858 95% CI: [-0.08729684  0.00587845]
# Bootstrap results for SFint-SR_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.027076822316091455 95% CI: [-0.07962735  0.01673784]
# Bootstrap results for SFinter-SFsup_left, nihtbx_flanker_agecorrected:
# R² mean: -0.02870741614473631 95% CI: [-0.07915345  0.00929026]
# Bootstrap results for SFinter-SFsup_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.04110018828991233 95% CI: [-0.08697759 -0.0018349 ]
# Bootstrap results for SFinter-SFsup_left, nihtbx_list_agecorrected:
# R² mean: -0.027546687579076537 95% CI: [-0.08281808  0.01408777]
# Bootstrap results for SFinter-SFsup_left, nihtbx_pattern_agecorrected:
# R² mean: -0.03361934412785813 95% CI: [-0.08850012  0.00556784]
# Bootstrap results for SFinter-SFsup_left, nihtbx_picvocab_agecorrected:
# R² mean: 0.0002673449969409695 95% CI: [-0.04996321  0.04228128]
# Bootstrap results for SFinter-SFsup_left, nihtbx_reading_agecorrected:
# R² mean: -0.036138273206543156 95% CI: [-0.09166834  0.00351278]
# Bootstrap results for SFinter-SFsup_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.0221522200970859 95% CI: [-0.0747304  0.0195952]
# Bootstrap results for SFinter-SFsup_left, nihtbx_cryst_agecorrected:
# R² mean: -0.022757299173911245 95% CI: [-0.07271324  0.01960388]
# Bootstrap results for SFinter-SFsup_left, nihtbx_totalcomp_agecorrected:
# R² mean: -0.010294885853487739 95% CI: [-0.06612003  0.03413739]
# Bootstrap results for SFinter-SFsup_right, nihtbx_flanker_agecorrected:
# R² mean: -0.048766323561454585 95% CI: [-0.0939141  -0.01181933]
# Bootstrap results for SFinter-SFsup_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.03197163468542906 95% CI: [-0.08847675  0.01056733]
# Bootstrap results for SFinter-SFsup_right, nihtbx_list_agecorrected:
# R² mean: -0.032405854929796626 95% CI: [-0.0888586   0.00754926]
# Bootstrap results for SFinter-SFsup_right, nihtbx_pattern_agecorrected:
# R² mean: -0.04396111898444131 95% CI: [-0.09851777 -0.00517312]
# Bootstrap results for SFinter-SFsup_right, nihtbx_picvocab_agecorrected:
# R² mean: -0

# Bootstrap results for SFmedian-SFpoltr-SFsup_right, nihtbx_reading_agecorrected:
# R² mean: -0.0498794852508429 95% CI: [-0.10050455 -0.01164615]
# Bootstrap results for SFmedian-SFpoltr-SFsup_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.031325320416274595 95% CI: [-0.08435836  0.00914849]
# Bootstrap results for SFmedian-SFpoltr-SFsup_right, nihtbx_cryst_agecorrected:
# R² mean: -0.044755067507412385 95% CI: [-0.08872968 -0.00876755]
# Bootstrap results for SFmedian-SFpoltr-SFsup_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.03194823117393254 95% CI: [-0.08407     0.01142776]
# Bootstrap results for SOr-SOlf_left, nihtbx_flanker_agecorrected:
# R² mean: -0.03644576117239957 95% CI: [-0.07949316 -0.00073686]
# Bootstrap results for SOr-SOlf_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.03844166373796689 95% CI: [-0.0889938  -0.00114085]
# Bootstrap results for SOr-SOlf_left, nihtbx_list_agecorrected:
# R² mean: -0.03921628805284251 95% CI: [-0.10136944  0.00306622]
# Bootstrap results for SOr-SOlf_left, nihtbx_pattern_agecorrected:
# R² mean: -0.030539203459343033 95% CI: [-0.08227512  0.00414532]
# Bootstrap results for SOr-SOlf_left, nihtbx_picvocab_agecorrected:
# R² mean: -0.030968888798155084 95% CI: [-0.07935546  0.00499498]
# Bootstrap results for SOr-SOlf_left, nihtbx_reading_agecorrected:
# R² mean: -0.03379765035412878 95% CI: [-0.08834284  0.00530473]
# Bootstrap results for SOr-SOlf_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.038147931407550524 95% CI: [-0.08957224 -0.00146237]
# Bootstrap results for SOr-SOlf_left, nihtbx_cryst_agecorrected:
# R² mean: -0.028737509954857264 95% CI: [-0.07616361  0.0093434 ]
# Bootstrap results for SOr-SOlf_left, nihtbx_totalcomp_agecorrected:
# R² mean: -0.03748052729225055 95% CI: [-0.08558245 -0.00218026]
# Bootstrap results for SOr-SOlf_right, nihtbx_flanker_agecorrected:
# R² mean: -0.04499328098048513 95% CI: [-0.09106675 -0.01154166]
# Bootstrap results for SOr-SOlf_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.027925619258556217 95% CI: [-0.08074002  0.00832561]
# Bootstrap results for SOr-SOlf_right, nihtbx_list_agecorrected:
# R² mean: -0.03082165262296747 95% CI: [-0.09070773  0.00394403]
# Bootstrap results for SOr-SOlf_right, nihtbx_pattern_agecorrected:
# R² mean: -0.03954473458025578 95% CI: [-0.08949972 -0.00626366]
# Bootstrap results for SOr-SOlf_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.014217039546174268 95% CI: [-0.07074408  0.02771235]
# Bootstrap results for SOr-SOlf_right, nihtbx_reading_agecorrected:
# R² mean: -0.02625226166996766 95% CI: [-0.08813226  0.01667726]
# Bootstrap results for SOr-SOlf_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.036353122000471284 95% CI: [-0.08410808 -0.00101109]
# Bootstrap results for SOr-SOlf_right, nihtbx_cryst_agecorrected:
# R² mean: -0.012795902716018034 95% CI: [-0.06346526  0.03056617]
# Bootstrap results for SOr-SOlf_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.022807189876130254 95% CI: [-0.08278937  0.01896618]
# Bootstrap results for SOr_left, nihtbx_flanker_agecorrected:
# R² mean: -0.03200096150517536 95% CI: [-0.08794022  0.00752275]
# Bootstrap results for SOr_left, nihtbx_cardsort_agecorrected:
# R² mean: -0.04198166913424029 95% CI: [-0.08986337 -0.00719161]
# Bootstrap results for SOr_left, nihtbx_list_agecorrected:
# R² mean: -0.03919483250876993 95% CI: [-0.09066071 -0.00011979]
# Bootstrap results for SOr_left, nihtbx_pattern_agecorrected:
# R² mean: -0.028919965351412148 95% CI: [-0.08432734  0.00658823]
# ...
# R² mean: -0.5993314916827605 95% CI: [-3.92946185  0.40190557]
# Bootstrap results for STi-SOTlat_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -2.053382059925404 95% CI: [-9.71432479 -0.28598418]
# Bootstrap results for STi-SOTlat_left, nihtbx_cryst_agecorrected:
# R² mean: -0.6502084897607444 95% CI: [-4.54381011  0.38447105]
# Bootstrap results for STi-SOTlat_left, nihtbx_totalcomp_agecorrected:
# R² mean: -1.138884301769156 95% CI: [-6.01494504  0.16441103]
# Bootstrap results for STi-SOTlat_right, nihtbx_flanker_agecorrected:
# R² mean: -1.6351063223127211 95% CI: [-6.52714281 -0.0488498 ]
# Bootstrap results for STi-SOTlat_right, nihtbx_cardsort_agecorrected:
# R² mean: -1.8054612134831447 95% CI: [-7.80492621 -0.19575365]
# Bootstrap results for STi-SOTlat_right, nihtbx_list_agecorrected:
# R² mean: -1.1003070723538293 95% CI: [-5.67999419  0.21298306]
# Bootstrap results for STi-SOTlat_right, nihtbx_pattern_agecorrected:
# R² mean: -2.2956132975209576 95% CI: [-9.23759271 -0.32208407]
# Bootstrap results for STi-SOTlat_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.940217209709211 95% CI: [-3.9534184   0.20415755]
# Bootstrap results for STi-SOTlat_right, nihtbx_reading_agecorrected:
# R² mean: -1.2726782050942018 95% CI: [-5.13394607  0.12024194]
# Bootstrap results for STi-SOTlat_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.510597409890735 95% CI: [-7.16007465e+00  3.69641921e-03]
# Bootstrap results for STi-SOTlat_right, nihtbx_cryst_agecorrected:
# R² mean: -1.0223256655753967 95% CI: [-4.4705045   0.16161489]
# Bootstrap results for STi-SOTlat_right, nihtbx_totalcomp_agecorrected:
# R² mean: -1.1249005714260232 95% CI: [-5.2144153   0.07382164]
# Bootstrap results for STi-STs-STpol_left, nihtbx_flanker_agecorrected:
# R² mean: -1.5674242509074714 95% CI: [-6.61310887 -0.10032097]
# Bootstrap results for STi-STs-STpol_left, nihtbx_cardsort_agecorrected:
# R² mean: -1.9945940923357508 95% CI: [-7.735025   -0.13765292]
# Bootstrap results for STi-STs-STpol_left, nihtbx_list_agecorrected:
# R² mean: -2.0589634314325185 95% CI: [-7.67004239 -0.12675147]
# Bootstrap results for STi-STs-STpol_left, nihtbx_pattern_agecorrected:
# R² mean: -1.8068195446949842 95% CI: [-7.26552155 -0.01405404]
# Bootstrap results for STi-STs-STpol_left, nihtbx_picvocab_agecorrected:
# R² mean: -1.0822547450015212 95% CI: [-5.01982315  0.28590481]
# Bootstrap results for STi-STs-STpol_left, nihtbx_reading_agecorrected:
# R² mean: -0.8610711857308856 95% CI: [-5.12302779  0.34210075]
# Bootstrap results for STi-STs-STpol_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.5327043292896851 95% CI: [-5.92803435  0.01237032]
# Bootstrap results for STi-STs-STpol_left, nihtbx_cryst_agecorrected:
# R² mean: -0.9354453427732582 95% CI: [-5.21040213  0.28555032]
# Bootstrap results for STi-STs-STpol_left, nihtbx_totalcomp_agecorrected:
# R² mean: -1.1243466295161184 95% CI: [-5.20830431  0.20789235]
# Bootstrap results for STi-STs-STpol_right, nihtbx_flanker_agecorrected:
# R² mean: -1.7191701598208853 95% CI: [-7.36493494 -0.18289621]
# Bootstrap results for STi-STs-STpol_right, nihtbx_cardsort_agecorrected:
# R² mean: -1.3120940004708208 95% CI: [-7.58799509  0.08102199]
# Bootstrap results for STi-STs-STpol_right, nihtbx_list_agecorrected:
# R² mean: -1.772994884474611 95% CI: [-5.96668608 -0.2241415 ]
# Bootstrap results for STi-STs-STpol_right, nihtbx_pattern_agecorrected:
# R² mean: -1.3211320249620246 95% CI: [-6.50117568  0.15227968]
# Bootstrap results for STi-STs-STpol_right, nihtbx_picvocab_agecorrected:
# R² mean: -1.0924761429324816 95% CI: [-6.81842413  0.31401494]
# Bootstrap results for STi-STs-STpol_right, nihtbx_reading_agecorrected:
# R² mean: -2.278759689431693 95% CI: [-9.87581932 -0.20479721]
# Bootstrap results for STi-STs-STpol_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.7574957432261624 95% CI: [-7.86824002 -0.01592575]
# Bootstrap results for STi-STs-STpol_right, nihtbx_cryst_agecorrected:
# R² mean: -1.779135769157706 95% CI: [-7.92735333  0.07997224]
# Bootstrap results for STi-STs-STpol_right, nihtbx_totalcomp_agecorrected:
# R² mean: -1.6961331648426683 95% CI: [-7.73620084 -0.02700733]
# Bootstrap results for STs_left, nihtbx_flanker_agecorrected:
# R² mean: -1.5026620507329056 95% CI: [-6.451527   -0.14699214]
# Bootstrap results for STs_left, nihtbx_cardsort_agecorrected:
# R² mean: -2.006029068856375 95% CI: [-8.92305302 -0.20363226]
# Bootstrap results for STs_left, nihtbx_list_agecorrected:
# R² mean: -2.0219731274978923 95% CI: [-7.85226766 -0.14172496]
# Bootstrap results for STs_left, nihtbx_pattern_agecorrected:
# R² mean: -2.451261618019958 95% CI: [-12.00368328  -0.15519328]
# Bootstrap results for STs_left, nihtbx_picvocab_agecorrected:
# R² mean: -0.9157123888786591 95% CI: [-5.51923402  0.27950324]
# Bootstrap results for STs_left, nihtbx_reading_agecorrected:
# R² mean: -0.551113800813365 95% CI: [-3.55759294  0.46530029]
# Bootstrap results for STs_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.7671511218548117 95% CI: [-7.47777301 -0.1636413 ]
# Bootstrap results for STs_left, nihtbx_cryst_agecorrected:
# R² mean: -0.7068536915856021 95% CI: [-4.54887569  0.33767858]
# Bootstrap results for STs_left, nihtbx_totalcomp_agecorrected:
# R² mean: -1.1022450148296628 95% CI: [-5.89658403  0.13593435]
# Bootstrap results for STs_right, nihtbx_flanker_agecorrected:
# R² mean: -1.5403691586827997 95% CI: [-6.1672627  -0.09816639]
# Bootstrap results for STs_right, nihtbx_cardsort_agecorrected:
# R² mean: -1.1674256493401483 95% CI: [-6.21173352  0.18781127]
# Bootstrap results for STs_right, nihtbx_list_agecorrected:
# R² mean: -1.4266328404025657 95% CI: [-5.91323479 -0.00789656]
# Bootstrap results for STs_right, nihtbx_pattern_agecorrected:
# R² mean: -0.9214522761285306 95% CI: [-5.15688653  0.32144149]
# Bootstrap results for STs_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.759485911432911 95% CI: [-4.96096871  0.4352829 ]
# Bootstrap results for STs_right, nihtbx_reading_agecorrected:
# R² mean: -2.065039274556168 95% CI: [-8.62226917 -0.17654188]
# Bootstrap results for STs_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.5443541315785398 95% CI: [-7.1463525   0.03805681]
# Bootstrap results for STs_right, nihtbx_cryst_agecorrected:
# R² mean: -1.5056741275902925 95% CI: [-7.63728471  0.12018276]
# Bootstrap results for STs_right, nihtbx_totalcomp_agecorrected:
# R² mean: -1.594965759133313 95% CI: [-7.45608458  0.07234493]
# Bootstrap results for STsbr_left, nihtbx_flanker_agecorrected:
# R² mean: -1.4641116857881586 95% CI: [-6.94502276  0.08913201]
# Bootstrap results for STsbr_left, nihtbx_cardsort_agecorrected:
# R² mean: -1.5860764217190724 95% CI: [-6.51931239 -0.11106986]
# Bootstrap results for STsbr_left, nihtbx_list_agecorrected:
# R² mean: -1.4708528479525038 95% CI: [-6.46159052e+00 -4.92636200e-03]
# Bootstrap results for STsbr_left, nihtbx_pattern_agecorrected:
# R² mean: -1.7858771838578402 95% CI: [-8.11161483 -0.13719621]
# Bootstrap results for STsbr_left, nihtbx_picvocab_agecorrected:
# R² mean: -1.258543796106872 95% CI: [-5.67577946  0.2608566 ]
# Bootstrap results for STsbr_left, nihtbx_reading_agecorrected:
# R² mean: -1.3848968957026457 95% CI: [-6.11795761  0.08146004]
# Bootstrap results for STsbr_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -2.084002099623011 95% CI: [-8.71958147 -0.1676494 ]
# Bootstrap results for STsbr_left, nihtbx_cryst_agecorrected:
# R² mean: -1.3198262494708004 95% CI: [-6.12090478  0.25147291]
# Bootstrap results for STsbr_left, nihtbx_totalcomp_agecorrected:
# R² mean: -1.5795677625573485 95% CI: [-7.57767545  0.00971006]
# Bootstrap results for STsbr_right, nihtbx_flanker_agecorrected:
# R² mean: -1.4375877521992049 95% CI: [-5.59721743 -0.03004619]
# Bootstrap results for STsbr_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.9295427474213276 95% CI: [-4.82589725  0.25561993]
# Bootstrap results for STsbr_right, nihtbx_list_agecorrected:
# R² mean: -1.8556085452032827 95% CI: [-7.0110238 -0.2009822]
# Bootstrap results for STsbr_right, nihtbx_pattern_agecorrected:
# R² mean: -1.5406841391932762 95% CI: [-7.63284754 -0.01087486]
# Bootstrap results for STsbr_right, nihtbx_picvocab_agecorrected:
# R² mean: -0.877697029946424 95% CI: [-4.27883601  0.25625101]
# Bootstrap results for STsbr_right, nihtbx_reading_agecorrected:
# R² mean: -1.8516792457768612 95% CI: [-7.58411853 -0.16620175]
# Bootstrap results for STsbr_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.6682334131102168 95% CI: [-6.17756925 -0.13795784]
# Bootstrap results for STsbr_right, nihtbx_cryst_agecorrected:
# R² mean: -1.3024797816523728 95% CI: [-6.41332562  0.05814306]
# Bootstrap results for STsbr_right, nihtbx_totalcomp_agecorrected:
# R² mean: -1.5175750448239302 95% CI: [-5.69238132 -0.14839403]
# Bootstrap results for ScCal-SLi_left, nihtbx_flanker_agecorrected:
# R² mean: -1.5595132145025028 95% CI: [-6.20031692  0.0894483 ]
# Bootstrap results for ScCal-SLi_left, nihtbx_cardsort_agecorrected:
# R² mean: -1.2151935993815708 95% CI: [-6.43028251  0.15297335]
# Bootstrap results for ScCal-SLi_left, nihtbx_list_agecorrected:
# R² mean: -1.7499461979799338 95% CI: [-8.07318987 -0.01571252]
# Bootstrap results for ScCal-SLi_left, nihtbx_pattern_agecorrected:
# R² mean: -1.396856956596973 95% CI: [-6.51095715  0.09259869]
# Bootstrap results for ScCal-SLi_left, nihtbx_picvocab_agecorrected:
# R² mean: -1.6347320461344867 95% CI: [-7.33219735e+00 -5.69923777e-03]
# Bootstrap results for ScCal-SLi_left, nihtbx_reading_agecorrected:
# R² mean: -1.6225319125307138 95% CI: [-6.82494284 -0.04009378]
# Bootstrap results for ScCal-SLi_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.513552863162597 95% CI: [-7.07324555  0.03173692]
# Bootstrap results for ScCal-SLi_left, nihtbx_cryst_agecorrected:
# R² mean: -1.7008956590205622 95% CI: [-7.16441202  0.0210479 ]
# Bootstrap results for ScCal-SLi_left, nihtbx_totalcomp_agecorrected:
# R² mean: -1.6660777980690258 95% CI: [-6.66001642 -0.01994819]
# Bootstrap results for ScCal-SLi_right, nihtbx_flanker_agecorrected:
# R² mean: -0.7705294206723068 95% CI: [-4.40141892  0.40106587]
# Bootstrap results for ScCal-SLi_right, nihtbx_cardsort_agecorrected:
# R² mean: -0.8217731763028399 95% CI: [-6.03116678  0.37143188]
# Bootstrap results for ScCal-SLi_right, nihtbx_list_agecorrected:
# R² mean: -1.0253295020341764 95% CI: [-4.26348049  0.22726244]
# Bootstrap results for ScCal-SLi_right, nihtbx_pattern_agecorrected:
# R² mean: -1.262227709679987 95% CI: [-5.88345852  0.07185577]
# Bootstrap results for ScCal-SLi_right, nihtbx_picvocab_agecorrected:
# R² mean: -1.239862161139286 95% CI: [-6.26321792  0.17732642]
# Bootstrap results for ScCal-SLi_right, nihtbx_reading_agecorrected:
# R² mean: -1.0276900342331816 95% CI: [-6.11397453  0.28737492]
# Bootstrap results for ScCal-SLi_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.4193237748378339 95% CI: [-3.72010368  0.55580031]
# Bootstrap results for ScCal-SLi_right, nihtbx_cryst_agecorrected:
# R² mean: -1.1420359870012624 95% CI: [-6.66167678  0.25537205]
# Bootstrap results for ScCal-SLi_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.8173983538643189 95% CI: [-4.62632166  0.30637983]
# Bootstrap results for SsP-SPaint_left, nihtbx_flanker_agecorrected:
# R² mean: -1.1366003972907128 95% CI: [-6.01879226  0.19548695]
# Bootstrap results for SsP-SPaint_left, nihtbx_cardsort_agecorrected:
# R² mean: -1.3449854783172996 95% CI: [-7.82832231  0.15054598]
# Bootstrap results for SsP-SPaint_left, nihtbx_list_agecorrected:
# R² mean: -0.7796659554669547 95% CI: [-4.32552381  0.30235416]
# Bootstrap results for SsP-SPaint_left, nihtbx_pattern_agecorrected:
# R² mean: -1.695990949756495 95% CI: [-8.9871695  -0.02057188]
# Bootstrap results for SsP-SPaint_left, nihtbx_picvocab_agecorrected:
# R² mean: -1.252901522466401 95% CI: [-5.83434655  0.15975071]
# Bootstrap results for SsP-SPaint_left, nihtbx_reading_agecorrected:
# R² mean: -1.428556951394712 95% CI: [-6.92523255  0.18913048]
# Bootstrap results for SsP-SPaint_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.1482344442614905 95% CI: [-5.27743018  0.19250146]
# Bootstrap results for SsP-SPaint_left, nihtbx_cryst_agecorrected:
# R² mean: -1.398109105822526 95% CI: [-7.09358047  0.23324211]
# Bootstrap results for SsP-SPaint_left, nihtbx_totalcomp_agecorrected:
# R² mean: -1.4968794411585478 95% CI: [-8.38499899  0.07449725]
# Bootstrap results for SsP-SPaint_right, nihtbx_flanker_agecorrected:
# R² mean: -0.7551126900090197 95% CI: [-4.21888473  0.27902983]
# Bootstrap results for SsP-SPaint_right, nihtbx_cardsort_agecorrected:
# R² mean: -1.6399212428140393 95% CI: [-7.52563316  0.05565561]
# Bootstrap results for SsP-SPaint_right, nihtbx_list_agecorrected:
# R² mean: -1.5537312661102343 95% CI: [-6.41086382e+00  2.64439245e-03]
# Bootstrap results for SsP-SPaint_right, nihtbx_pattern_agecorrected:
# R² mean: -0.8685095007356519 95% CI: [-5.89000131  0.38103784]
# Bootstrap results for SsP-SPaint_right, nihtbx_picvocab_agecorrected:
# R² mean: -1.4167837611976366 95% CI: [-7.2124816   0.09192927]
# Bootstrap results for SsP-SPaint_right, nihtbx_reading_agecorrected:
# R² mean: -0.6264337400172844 95% CI: [-4.17598599  0.39282316]
# Bootstrap results for SsP-SPaint_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.6434275071248033 95% CI: [-3.72264194  0.38790965]
# Bootstrap results for SsP-SPaint_right, nihtbx_cryst_agecorrected:
# R² mean: -0.9374421378385219 95% CI: [-5.33961901  0.31105566]
# Bootstrap results for SsP-SPaint_right, nihtbx_totalcomp_agecorrected:
# R² mean: -0.5739253489132683 95% CI: [-4.26455838  0.38443843]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_flanker_agecorrected:
# R² mean: -1.8817018657424702 95% CI: [-10.52984732  -0.08432269]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_cardsort_agecorrected:
# R² mean: -1.409632015420386 95% CI: [-7.95544261  0.12839651]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_list_agecorrected:
# R² mean: -0.9581255848540399 95% CI: [-5.26929596  0.21588655]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_pattern_agecorrected:
# R² mean: -1.123926857450297 95% CI: [-7.59509904  0.25724961]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_picvocab_agecorrected:
# R² mean: -1.6662680482839238 95% CI: [-7.5194213  -0.09578625]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_reading_agecorrected:
# R² mean: -1.040264919288236 95% CI: [-4.16983968  0.14564145]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_fluidcomp_agecorrected:
# R² mean: -0.9428530303068725 95% CI: [-5.56528429  0.36542627]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_cryst_agecorrected:
# R² mean: -1.3773848142395921 95% CI: [-6.02757967  0.01861822]
# Bootstrap results for fronto-parietal_medial_face_left, nihtbx_totalcomp_agecorrected:
# R² mean: -1.2432537528597911 95% CI: [-6.31570463  0.18990412]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_flanker_agecorrected:
# R² mean: -0.8417896031616671 95% CI: [-4.62750845  0.31423581]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_cardsort_agecorrected:
# R² mean: -1.7801732245762047 95% CI: [-8.99672826 -0.04804586]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_list_agecorrected:
# R² mean: -1.264954879311089 95% CI: [-6.51808271  0.07787648]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_pattern_agecorrected:
# R² mean: -1.7046062736669403 95% CI: [-9.26683503  0.03013709]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_picvocab_agecorrected:
# R² mean: -1.9918541279195012 95% CI: [-10.1061466   -0.14870904]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_reading_agecorrected:
# R² mean: -1.0133432204882669 95% CI: [-5.6494136   0.27957296]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_fluidcomp_agecorrected:
# R² mean: -1.1526130373314902 95% CI: [-4.97996972  0.23675035]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_cryst_agecorrected:
# R² mean: -1.4113396468356698 95% CI: [-7.60065456  0.10996701]
# Bootstrap results for fronto-parietal_medial_face_right, nihtbx_totalcomp_agecorrected:
# R² mean: -1.1584808479839233 95% CI: [-6.08682808  0.20339088]
