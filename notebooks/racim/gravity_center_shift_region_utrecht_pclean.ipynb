# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import json

# %%
# Read the sulci-region mapping dictionary from json file
def read_sulci_region_mapping(file_path):
    with open(file_path, 'r') as file:
        mapping = json.load(file)
    return mapping

json_path = "/neurospin/dico/data/deep_folding/current/sulci_regions_gridsearch.json"

mapping = read_sulci_region_mapping(json_path)


print(mapping)
# Out:
# {'brain': {'S.C.-sylv._left': {'S.C._left': ['S.C._left'], 'S.C.sylvian._left': ['S.C.sylvian._left']}, 'S.C.-S.Pe.C._left': {'S.C._left': ['S.C._left'], 'S.C.sylvian._left': ['S.C.sylvian._left'], 'S.Pe.C.inf._left': ['S.Pe.C.inf._left'], 'S.Pe.C.inter._left': ['S.Pe.C.inter._left'], 'S.Pe.C.marginal._left': ['S.Pe.C.marginal._left'], 'S.Pe.C.sup._left': ['S.Pe.C.sup._left'], 'S.Pe.C.median._left': ['S.Pe.C.median._left']}, 'S.C.-S.Po.C._left': {'S.C._left': ['S.C._left'], 'S.C.sylvian._left': ['S.C.sylvian._left'], 'S.Po.C.sup._left': ['S.Po.C.sup._left'], 'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left'], 'F.C.L.r.retroC.tr._left': ['F.C.L.r.retroC.tr._left']}, 'S.Pe.C._left': {'S.Pe.C.inf._left': ['S.Pe.C.inf._left'], 'S.Pe.C.inter._left': ['S.Pe.C.inter._left'], 'S.Pe.C.marginal._left': ['S.Pe.C.marginal._left'], 'S.Pe.C.sup._left': ['S.Pe.C.sup._left'], 'S.Pe.C.median._left': ['S.Pe.C.median._left']}, 'S.Po.C._left': {'S.Po.C.sup._left': ['S.Po.C.sup._left'], 'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left'], 'F.C.L.r.retroC.tr._left': ['F.C.L.r.retroC.tr._left']}, 'CINGULATE._left': {'paracingular._left': ['paracingular._left'], 'F.C.M.ant._left': ['F.C.M.ant._left']}, 'S.F.int.-F.C.M.ant._left': {'F.C.M.ant._left': ['F.C.M.ant._left'], 'S.F.int._left': ['S.F.int._left']}, 'S.F.inf.-BROCA-S.Pe.C.inf._left': {'S.F.inf._left': ['S.F.inf._left'], 'S.F.inf.ant._left': ['S.F.inf.ant._left'], 'F.C.L.r.ant._left': ['F.C.L.r.ant._left'], 'F.C.L.r.asc._left': ['F.C.L.r.asc._left'], 'F.C.L.r.diag._left': ['F.C.L.r.diag._left'], 'S.Pe.C.inf._left': ['S.Pe.C.inf._left']}, 'S.T.s._left': {'S.T.s._left': ['S.T.s._left']}, 'Sc.Cal.-S.Li._left': {'F.Cal.ant.-Sc.Cal._left': ['F.Cal.ant.-Sc.Cal._left'], 'S.O.p._left': ['S.O.p._left'], 'S.Li.ant._left': ['S.Li.ant._left'], 'S.Li.post._left': ['S.Li.post._left']}, 'F.C.M.post.-S.p.C._left': {'F.C.M.post._left': ['F.C.M.post._left'], 'S.C.LPC._left': ['S.C.LPC._left'], 'S.p.C._left': ['S.p.C._left']}, 'S.T.i.-S.O.T.lat._left': {'S.T.i.ant._left': ['S.T.i.ant._left'], 'S.T.i.post._left': ['S.T.i.post._left'], 'S.O.T.lat.ant._left': ['S.O.T.lat.ant._left'], 'S.O.T.lat.int._left': ['S.O.T.lat.int._left'], 'S.O.T.lat.med._left': ['S.O.T.lat.med._left'], 'S.O.T.lat.post._left': ['S.O.T.lat.post._left']}, 'OCCIPITAL_left': {'OCCIPITAL_left': ['OCCIPITAL_left']}, 'F.I.P._left': {'F.I.P._left': ['F.I.P._left']}, 'F.I.P.-F.I.P.Po.C.inf._left': {'F.I.P._left': ['F.I.P._left'], 'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left']}, 'S.F.inter.-S.F.sup._left': {'S.F.inter._left': ['S.F.inter._left'], 'S.F.sup._left': ['S.F.sup._left']}, 'S.F.median-S.F.pol.tr.-S.F.sup._left': {'S.F.median._left': ['S.F.median._left'], 'S.F.polaire.tr._left': ['S.F.polaire.tr._left'], 'S.F.sup._left': ['S.F.sup._left']}, 'S.Or._left': {'S.Or._left': ['S.Or._left']}, 'S.Or.-S.Olf._left': {'S.Or._left': ['S.Or._left'], 'S.Olf._left': ['S.Olf._left']}, 'F.P.O.-S.Cu.-Sc.Cal._left': {'F.P.O._left': ['F.P.O._left'], 'S.Pa.t._left': ['S.Pa.t._left'], 'S.Cu._left': ['S.Cu._left'], 'F.Cal.ant.-Sc.Cal._left': ['F.Cal.ant.-Sc.Cal._left'], 'S.O.p._left': ['S.O.p._left']}, 'S.s.P.-S.Pa.int._left': {'S.s.P._left': ['S.s.P._left'], 'S.Pa.int._left': ['S.Pa.int._left']}, 'S.T.s.br._left': {'F.I.P.r.int.1_left': ['F.I.P.r.int.1_left'], 'F.I.P.r.int.2_left': ['F.I.P.r.int.2_left'], 'S.T.s.ter.asc.ant._left': ['S.T.s.ter.asc.ant._left'], 'S.T.s.ter.asc.post._left': ['S.T.s.ter.asc.post._left'], 'S.GSM._left': ['S.GSM._left']}, 'Lobule_parietal_sup._left': {'F.I.P._left': ['F.I.P._left'], 'S.Po.C.sup._left': ['S.Po.C.sup._left'], 'S.Pa.sup._left': ['S.Pa.sup._left']}, 'S.F.marginal-S.F.inf.ant._left': {'S.F.marginal._left': ['S.F.marginal._left'], 'S.F.orbitaire._left': ['S.F.orbitaire._left'], 'S.F.inf.ant._left': ['S.F.inf.ant._left']}, 'F.Coll.-S.Rh._left': {'F.Coll._left': ['F.Coll._left'], 'S.Rh._left': ['S.Rh._left']}, 'S.T.i.-S.T.s.-S.T.pol._left': {'S.T.i.ant._left': ['S.T.i.ant._left'], 'S.T.i.post._left': ['S.T.i.post._left'], 'S.T.s._ ...

# %%
def get_file_list(base_path='/neurospin/dico/data/human/pclean/derivatives/morphologist-2021/morphometry/3.3_base2018/morpho_talairach'):
    files= []
    # Get the list of files in the directory
    for file in os.listdir(base_path):
        # Check if the file ends with .csv
        if file.endswith(".dat"):
            files.append(file)
    files.remove("morpho_S.Or.l._left.dat")
    files.remove("morpho_F.C.M.r.AMS.ant._left.dat")
    files.remove("morpho_S.Or.l._right.dat")
    files.remove("morpho_F.C.M.r.AMS.ant._right.dat")

    return files

def get_sulci_list(base_path='/neurospin/dico/data/human/pclean/derivatives/morphologist-2021/morphometry/3.3_base2018/morpho_talairach'):
    files = get_file_list(base_path)
    sulci_list = [x.split('.dat')[0].split('morpho_')[1] for x in files]

    return sulci_list

# %%
print(get_sulci_list('/neurospin/dico/data/human/pclean/derivatives/morphologist-2021/morphometry/3.3_base2018/morpho_talairach'))
# Out:
# ['F.Cal.ant.-Sc.Cal._left', 'F.I.P.r.int.1_right', 'F.C.L.r.diag._right', 'S.F.inf._right', 'F.I.P.r.int.1_left', 'S.Pe.C.marginal._left', 'F.C.L.r.retroC.tr._left', 'F.C.L.r.sc.post._left', 'S.T.i.post._left', 'F.C.L.r.asc._left', 'F.C.L.r.sc.ant._right', 'S.F.sup._left', 'S.F.marginal._left', 'F.C.L.a._right', 'S.O.T.lat.ant._right', 'F.P.O._left', 'S.Call._left', 'S.F.orbitaire._right', 'S.R.sup._left', 'F.Coll._right', 'ventricle_left', 'S.T.s.ter.asc.ant._right', 'S.Pe.C.inter._left', 'F.I.P.Po.C.inf._right', 'S.O.T.lat.ant._left', 'S.C._left', 'F.C.L.a._left', 'S.C.LPC._left', 'S.Pe.C.marginal._right', 'S.Olf._left', 'S.R.inf._right', 'S.Li._right', 'F.C.L.r.retroC.tr._right', 'S.F.int._right', 'F.Cal.ant.-Sc.Cal._right', 'S.Po.C.sup._left', 'S.p.C._right', 'S.Pe.C.median._right', 'INSULA_right', 'S.Pe.C.median._left', 'S.T.s.ter.asc.post._right', 'S.Pa.sup._right', 'F.C.L.r.asc._right', 'S.Li._left', 'S.Or._left', 'S.F.median._left', 'S.F.median._right', 'S.T.pol._right', 'S.Po.C.sup._right', 'S.F.inf._left', 'F.C.L.r.diag._left', 'S.T.s.ter.asc.ant._left', 'S.Rh._right', 'S.Pa.t._right', 'S.O.p._right', 'S.Call._right', 'S.Pa.sup._left', 'F.C.L.r.ant._right', 'S.Rh._left', 'S.F.orbitaire._left', 'S.T.s.ter.asc.post._left', 'F.C.L.p._right', 'F.I.P._right', 'S.R.inf._left', 'S.O.T.lat.post._right', 'S.R.sup._right', 'S.Pe.C.inf._left', 'F.C.M.post._right', 'S.Pe.C.inter._right', 'OCCIPITAL_left', 'F.C.L.r.sc.ant._left', 'S.C.LPC._right', 'S.Cu._left', 'F.C.M.post._left', 'F.C.M.ant._left', 'S.Pa.int._right', 'S.Cu._right', 'S.T.pol._left', 'F.I.P.r.int.2_right', 'OCCIPITAL_right', 'S.O.p._left', 'F.C.L.p._left', 'S.F.int._left', 'S.T.i.ant._right', 'S.T.s._right', 'S.Pa.t._left', 'S.Pe.C.inf._right', 'INSULA_left', 'S.F.inter._left', 'S.F.polaire.tr._right', 'S.Olf._right', 'S.F.polaire.tr._left', 'S.Pa.int._left', 'S.O.T.lat.post._left', 'F.C.L.r.sc.post._right', 'S.p.C._left', 'F.C.M.ant._right', 'F.I.P._left', 'S.F.marginal._right', 'F.I.P.r.int.2_left', 'F.C.L.r.ant._left', 'S.F.sup._right', 'S.T.s._left', 'S.Pe.C.sup._left', 'S.C._right', 'F.P.O._right', 'S.s.P._right', 'S.Or._right', 'S.Pe.C.sup._right', 'ventricle_right', 'S.s.P._left', 'F.Coll._left', 'S.T.i.ant._left', 'S.F.inter._right', 'S.T.i.post._right', 'F.I.P.Po.C.inf._left']

# %%
print(get_sulci_list('/neurospin/dico/data/human/utrecht/derivatives/morphologist-2023/morphometry/40wks/morpho_talairach'))
# Out:
# ['F.Cal.ant.-Sc.Cal._left', 'F.I.P.r.int.1_right', 'F.C.L.r.diag._right', 'S.F.inf._right', 'F.I.P.r.int.1_left', 'S.Pe.C.marginal._left', 'F.C.L.r.retroC.tr._left', 'F.C.L.r.sc.post._left', 'S.T.i.post._left', 'F.C.L.r.asc._left', 'F.C.L.r.sc.ant._right', 'S.F.sup._left', 'S.F.marginal._left', 'F.C.L.a._right', 'S.O.T.lat.ant._right', 'F.P.O._left', 'S.Call._left', 'S.F.orbitaire._right', 'S.R.sup._left', 'F.Coll._right', 'ventricle_left', 'S.T.s.ter.asc.ant._right', 'S.Pe.C.inter._left', 'F.I.P.Po.C.inf._right', 'S.O.T.lat.ant._left', 'S.C._left', 'F.C.L.a._left', 'S.C.LPC._left', 'S.Pe.C.marginal._right', 'S.Olf._left', 'S.R.inf._right', 'S.Li._right', 'F.C.L.r.retroC.tr._right', 'S.F.int._right', 'F.Cal.ant.-Sc.Cal._right', 'S.Po.C.sup._left', 'S.p.C._right', 'S.Pe.C.median._right', 'INSULA_right', 'S.Pe.C.median._left', 'S.T.s.ter.asc.post._right', 'S.Pa.sup._right', 'F.C.L.r.asc._right', 'S.Li._left', 'S.Or._left', 'S.F.median._left', 'S.F.median._right', 'S.T.pol._right', 'S.Po.C.sup._right', 'S.F.inf._left', 'F.C.L.r.diag._left', 'S.T.s.ter.asc.ant._left', 'S.Rh._right', 'S.Pa.t._right', 'S.O.p._right', 'S.Call._right', 'S.Pa.sup._left', 'F.C.L.r.ant._right', 'S.Rh._left', 'S.F.orbitaire._left', 'S.T.s.ter.asc.post._left', 'F.C.L.p._right', 'F.I.P._right', 'S.R.inf._left', 'S.O.T.lat.post._right', 'S.R.sup._right', 'S.Pe.C.inf._left', 'F.C.M.post._right', 'S.Pe.C.inter._right', 'OCCIPITAL_left', 'F.C.L.r.sc.ant._left', 'S.C.LPC._right', 'S.Cu._left', 'F.C.M.post._left', 'F.C.M.ant._left', 'S.Pa.int._right', 'S.Cu._right', 'S.T.pol._left', 'F.I.P.r.int.2_right', 'OCCIPITAL_right', 'S.O.p._left', 'F.C.L.p._left', 'S.F.int._left', 'S.T.i.ant._right', 'S.T.s._right', 'S.Pa.t._left', 'S.Pe.C.inf._right', 'INSULA_left', 'S.F.inter._left', 'S.F.polaire.tr._right', 'S.Olf._right', 'S.F.polaire.tr._left', 'S.Pa.int._left', 'S.O.T.lat.post._left', 'F.C.L.r.sc.post._right', 'S.p.C._left', 'F.C.M.ant._right', 'F.I.P._left', 'S.F.marginal._right', 'F.I.P.r.int.2_left', 'F.C.L.r.ant._left', 'S.F.sup._right', 'S.T.s._left', 'S.Pe.C.sup._left', 'S.C._right', 'F.P.O._right', 'S.s.P._right', 'S.Or._right', 'S.Pe.C.sup._right', 'ventricle_right', 'S.s.P._left', 'F.Coll._left', 'S.T.i.ant._left', 'S.F.inter._right', 'S.T.i.post._right', 'F.I.P.Po.C.inf._left']

# %%
def map_sulcus_to_all_regions(sulcus, mapping):
    """
    Return a list of all region‐names under mapping['brain'] 
    in which 'sulcus' appears.
    """
    hits = []
    for region_name, sub_dict in mapping["brain"].items():
        for key_sulcus, list_values in sub_dict.items():
            if sulcus in list_values:
                hits.append(region_name)
                break  
    return hits


def map_sulci_to_all_regions(sulci_list, mapping):

    result = {}
    for sulcus in sulci_list:
        result[sulcus] = map_sulcus_to_all_regions(sulcus, mapping)
    return result


# Example usage
sulci_list= get_sulci_list('/neurospin/dico/data/human/utrecht/derivatives/morphologist-2023/morphometry/40wks/morpho_talairach')
sulcus_to_regions = map_sulci_to_all_regions(sulci_list, mapping)

# Affichage rapide :
for sulcus, regs in sulcus_to_regions.items():
    if len(regs) >= 0:
        print(f"{sulcus} : {regs}")
# Out:
# F.Cal.ant.-Sc.Cal._left : ['Sc.Cal.-S.Li._left', 'F.P.O.-S.Cu.-Sc.Cal._left']
# F.I.P.r.int.1_right : ['S.T.s.br._right']
# F.C.L.r.diag._right : ['S.F.inf.-BROCA-S.Pe.C.inf._right']
# S.F.inf._right : ['S.F.inf.-BROCA-S.Pe.C.inf._right']
# F.I.P.r.int.1_left : ['S.T.s.br._left']
# S.Pe.C.marginal._left : ['S.C.-S.Pe.C._left', 'S.Pe.C._left']
# F.C.L.r.retroC.tr._left : ['S.C.-S.Po.C._left', 'S.Po.C._left']
# F.C.L.r.sc.post._left : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._left']
# S.T.i.post._left : ['S.T.i.-S.O.T.lat._left', 'S.T.i.-S.T.s.-S.T.pol._left']
# F.C.L.r.asc._left : ['S.F.inf.-BROCA-S.Pe.C.inf._left']
# F.C.L.r.sc.ant._right : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._right']
# S.F.sup._left : ['S.F.inter.-S.F.sup._left', 'S.F.median-S.F.pol.tr.-S.F.sup._left']
# S.F.marginal._left : ['S.F.marginal-S.F.inf.ant._left']
# F.C.L.a._right : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._right']
# S.O.T.lat.ant._right : ['S.T.i.-S.O.T.lat._right', 'deMatos._right', 'deMatos_polar._right']
# F.P.O._left : ['F.P.O.-S.Cu.-Sc.Cal._left']
# S.Call._left : ['fronto-parietal_medial_face._left']
# S.F.orbitaire._right : ['S.F.marginal-S.F.inf.ant._right']
# S.R.sup._left : ['S.F.int.-S.R._left', 'fronto-parietal_medial_face._left']
# F.Coll._right : ['deMatos._right', 'deMatos_polar._right', 'F.Coll.-S.Rh._right']
# ventricle_left : []
# S.T.s.ter.asc.ant._right : ['S.T.s.br._right']
# S.Pe.C.inter._left : ['S.C.-S.Pe.C._left', 'S.Pe.C._left']
# F.I.P.Po.C.inf._right : ['S.C.-S.Po.C._right', 'S.Po.C._right', 'F.I.P.-F.I.P.Po.C.inf._right']
# S.O.T.lat.ant._left : ['S.T.i.-S.O.T.lat._left', 'deMatos._left', 'deMatos_polar._left']
# S.C._left : ['S.C.-sylv._left', 'S.C.-S.Pe.C._left', 'S.C.-S.Po.C._left']
# F.C.L.a._left : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._left']
# S.C.LPC._left : ['F.C.M.post.-S.p.C._left', 'fronto-parietal_medial_face._left', 'LARGE_CINGULATE._left']
# S.Pe.C.marginal._right : ['S.C.-S.Pe.C._right', 'S.Pe.C._right']
# S.Olf._left : ['S.Or.-S.Olf._left']
# S.R.inf._right : ['S.F.int.-S.R._right']
# S.Li._right : []
# F.C.L.r.retroC.tr._right : ['S.C.-S.Po.C._right', 'S.Po.C._right']
# S.F.int._right : ['LARGE_CINGULATE._right', 'S.F.int.-F.C.M.ant._right', 'S.F.int.-S.R._right', 'fronto-parietal_medial_face._right']
# F.Cal.ant.-Sc.Cal._right : ['Sc.Cal.-S.Li._right', 'F.P.O.-S.Cu.-Sc.Cal._right']
# S.Po.C.sup._left : ['S.C.-S.Po.C._left', 'S.Po.C._left', 'Lobule_parietal_sup._left']
# S.p.C._right : ['LARGE_CINGULATE._right', 'F.C.M.post.-S.p.C._right', 'fronto-parietal_medial_face._right']
# S.Pe.C.median._right : ['S.C.-S.Pe.C._right', 'S.Pe.C._right']
# INSULA_right : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._right']
# S.Pe.C.median._left : ['S.C.-S.Pe.C._left', 'S.Pe.C._left']
# S.T.s.ter.asc.post._right : ['S.T.s.br._right']
# S.Pa.sup._right : ['Lobule_parietal_sup._right']
# F.C.L.r.asc._right : ['S.F.inf.-BROCA-S.Pe.C.inf._right']
# S.Li._left : []
# S.Or._left : ['S.Or._left', 'S.Or.-S.Olf._left']
# S.F.median._left : ['S.F.median-S.F.pol.tr.-S.F.sup._left']
# S.F.median._right : ['S.F.median-S.F.pol.tr.-S.F.sup._right']
# S.T.pol._right : ['deMatos_polar._right', 'S.T.i.-S.T.s.-S.T.pol._right']
# S.Po.C.sup._right : ['S.C.-S.Po.C._right', 'S.Po.C._right', 'Lobule_parietal_sup._right']
# S.F.inf._left : ['S.F.inf.-BROCA-S.Pe.C.inf._left']
# F.C.L.r.diag._left : ['S.F.inf.-BROCA-S.Pe.C.inf._left']
# S.T.s.ter.asc.ant._left : ['S.T.s.br._left']
# S.Rh._right : ['deMatos._right', 'deMatos_polar._right', 'F.Coll.-S.Rh._right']
# S.Pa.t._right : ['F.P.O.-S.Cu.-Sc.Cal._right']
# S.O.p._right : ['Sc.Cal.-S.Li._right', 'F.P.O.-S.Cu.-Sc.Cal._right']
# S.Call._right : ['fronto-parietal_medial_face._right']
# S.Pa.sup._left : ['Lobule_parietal_sup._left']
# F.C.L.r.ant._right : ['S.F.inf.-BROCA-S.Pe.C.inf._right']
# S.Rh._left : ['F.Coll.-S.Rh._left', 'deMatos._left', 'deMatos_polar._left']
# S.F.orbitaire._left : ['S.F.marginal-S.F.inf.ant._left']
# S.T.s.ter.asc.post._left : ['S.T.s.br._left']
# F.C.L.p._right : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._right', 'F.C.L.p.-S.GSM._right']
# F.I.P._right : ['F.I.P._right', 'F.I.P.-F.I.P.Po.C.inf._right', 'Lobule_parietal_sup._right']
# S.R.inf._left : ['S.F.int.-S.R._left']
# S.O.T.lat.post._right : ['S.T.i.-S.O.T.lat._right', 'deMatos._right', 'deMatos_polar._right']
# S.R.sup._right : ['S.F.int.-S.R._right', 'fronto-parietal_medial_face._right']
# S.Pe.C.inf._left : ['S.C.-S.Pe.C._left', 'S.Pe.C._left', 'S.F.inf.-BROCA-S.Pe.C.inf._left']
# F.C.M.post._right : ['LARGE_CINGULATE._right', 'F.C.M.post.-S.p.C._right', 'fronto-parietal_medial_face._right']
# S.Pe.C.inter._right : ['S.C.-S.Pe.C._right', 'S.Pe.C._right']
# OCCIPITAL_left : ['OCCIPITAL_left']
# F.C.L.r.sc.ant._left : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._left']
# S.C.LPC._right : ['LARGE_CINGULATE._right', 'F.C.M.post.-S.p.C._right', 'fronto-parietal_medial_face._right']
# S.Cu._left : ['F.P.O.-S.Cu.-Sc.Cal._left']
# F.C.M.post._left : ['F.C.M.post.-S.p.C._left', 'fronto-parietal_medial_face._left', 'LARGE_CINGULATE._left']
# F.C.M.ant._left : ['CINGULATE._left', 'S.F.int.-F.C.M.ant._left', 'fronto-parietal_medial_face._left', 'LARGE_CINGULATE._left']
# S.Pa.int._right : ['S.s.P.-S.Pa.int._right', 'fronto-parietal_medial_face._right']
# S.Cu._right : ['F.P.O.-S.Cu.-Sc.Cal._right']
# S.T.pol._left : ['S.T.i.-S.T.s.-S.T.pol._left', 'deMatos_polar._left']
# F.I.P.r.int.2_right : ['S.T.s.br._right']
# OCCIPITAL_right : ['OCCIPITAL_right']
# S.O.p._left : ['Sc.Cal.-S.Li._left', 'F.P.O.-S.Cu.-Sc.Cal._left']
# F.C.L.p._left : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._left', 'F.C.L.p.-S.GSM._left']
# S.F.int._left : ['S.F.int.-F.C.M.ant._left', 'S.F.int.-S.R._left', 'fronto-parietal_medial_face._left', 'LARGE_CINGULATE._left']
# S.T.i.ant._right : ['S.T.i.-S.O.T.lat._right', 'S.T.i.-S.T.s.-S.T.pol._right']
# S.T.s._right : ['S.T.s._right', 'S.T.i.-S.T.s.-S.T.pol._right', 'S.T.s.-S.GSM._right']
# S.Pa.t._left : ['F.P.O.-S.Cu.-Sc.Cal._left']
# S.Pe.C.inf._right : ['S.C.-S.Pe.C._right', 'S.Pe.C._right', 'S.F.inf.-BROCA-S.Pe.C.inf._right']
# INSULA_left : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._left']
# S.F.inter._left : ['S.F.inter.-S.F.sup._left']
# S.F.polaire.tr._right : ['S.F.median-S.F.pol.tr.-S.F.sup._right']
# S.Olf._right : ['S.Or.-S.Olf._right']
# S.F.polaire.tr._left : ['S.F.median-S.F.pol.tr.-S.F.sup._left']
# S.Pa.int._left : ['S.s.P.-S.Pa.int._left', 'fronto-parietal_medial_face._left']
# S.O.T.lat.post._left : ['S.T.i.-S.O.T.lat._left', 'deMatos._left', 'deMatos_polar._left']
# F.C.L.r.sc.post._right : ['F.C.L.p.-subsc.-F.C.L.a.-INSULA._right']
# S.p.C._left : ['F.C.M.post.-S.p.C._left', 'fronto-parietal_medial_face._left', 'LARGE_CINGULATE._left']
# F.C.M.ant._right : ['LARGE_CINGULATE._right', 'CINGULATE._right', 'S.F.int.-F.C.M.ant._right', 'fronto-parietal_medial_face._right']
# F.I.P._left : ['F.I.P._left', 'F.I.P.-F.I.P.Po.C.inf._left', 'Lobule_parietal_sup._left']
# S.F.marginal._right : ['S.F.marginal-S.F.inf.ant._right']
# F.I.P.r.int.2_left : ['S.T.s.br._left']
# F.C.L.r.ant._left : ['S.F.inf.-BROCA-S.Pe.C.inf._left']
# S.F.sup._right : ['S.F.inter.-S.F.sup._right', 'S.F.median-S.F.pol.tr.-S.F.sup._right']
# S.T.s._left : ['S.T.s._left', 'S.T.i.-S.T.s.-S.T.pol._left', 'S.T.s.-S.GSM._left']
# S.Pe.C.sup._left : ['S.C.-S.Pe.C._left', 'S.Pe.C._left']
# S.C._right : ['S.C.-sylv._right', 'S.C.-S.Pe.C._right', 'S.C.-S.Po.C._right']
# F.P.O._right : ['F.P.O.-S.Cu.-Sc.Cal._right']
# S.s.P._right : ['S.s.P.-S.Pa.int._right', 'fronto-parietal_medial_face._right']
# S.Or._right : ['S.Or._right', 'S.Or.-S.Olf._right']
# S.Pe.C.sup._right : ['S.C.-S.Pe.C._right', 'S.Pe.C._right']
# ventricle_right : []
# S.s.P._left : ['S.s.P.-S.Pa.int._left', 'fronto-parietal_medial_face._left']
# F.Coll._left : ['F.Coll.-S.Rh._left', 'deMatos._left', 'deMatos_polar._left']
# S.T.i.ant._left : ['S.T.i.-S.O.T.lat._left', 'S.T.i.-S.T.s.-S.T.pol._left']
# S.F.inter._right : ['S.F.inter.-S.F.sup._right']
# S.T.i.post._right : ['S.T.i.-S.O.T.lat._right', 'S.T.i.-S.T.s.-S.T.pol._right']
# F.I.P.Po.C.inf._left : ['S.C.-S.Po.C._left', 'S.Po.C._left', 'F.I.P.-F.I.P.Po.C.inf._left']

# %%
def group_by_region(sulci_list, regions):
    region_dict = {}
    for region in regions:
        region_dict[region] = []
    for sulcus in sulci_list:
        if sulcus in sulcus_to_regions.keys():
            for region in sulcus_to_regions[sulcus]:
                if region in region_dict.keys():
                    region_dict[region].append(sulcus)
    return region_dict


regions = list(set(region for region_list in sulcus_to_regions.values() for region in region_list))
print("Regions found:", regions)



region_dict = group_by_region(sulci_list,regions)
region_dict["S.F.int.-F.C.M.ant._right"].append('S.R.sup._right')
region_dict["S.F.int.-F.C.M.ant._left"].append('S.R.sup._left')
region_dict["LARGE_CINGULATE._left"].append('S.R.sup._left')
region_dict["LARGE_CINGULATE._right"].append('S.R.sup._right')



print("Sulci grouped by regions:")
# Display the grouped sulci by region
for region, sulci in region_dict.items():
    print(f"{region}: {sulci}")
# Out:
# Regions found: ['S.T.s.-S.GSM._left', 'S.F.int.-F.C.M.ant._right', 'Sc.Cal.-S.Li._left', 'F.I.P.-F.I.P.Po.C.inf._left', 'S.F.inter.-S.F.sup._right', 'S.Or.-S.Olf._left', 'Lobule_parietal_sup._left', 'OCCIPITAL_right', 'S.Po.C._left', 'S.F.marginal-S.F.inf.ant._left', 'S.F.marginal-S.F.inf.ant._right', 'F.P.O.-S.Cu.-Sc.Cal._left', 'S.T.s.br._right', 'S.F.int.-S.R._right', 'S.T.s.-S.GSM._right', 'S.Pe.C._left', 'S.C.-S.Pe.C._right', 'CINGULATE._right', 'deMatos._left', 'S.F.int.-F.C.M.ant._left', 'S.C.-sylv._right', 'deMatos._right', 'S.T.s.br._left', 'S.T.i.-S.T.s.-S.T.pol._left', 'F.I.P._left', 'S.F.median-S.F.pol.tr.-S.F.sup._left', 'F.P.O.-S.Cu.-Sc.Cal._right', 'F.C.M.post.-S.p.C._left', 'fronto-parietal_medial_face._right', 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left', 'S.C.-S.Pe.C._left', 'S.F.inter.-S.F.sup._left', 'Lobule_parietal_sup._right', 'F.Coll.-S.Rh._left', 'S.F.inf.-BROCA-S.Pe.C.inf._left', 'F.I.P._right', 'OCCIPITAL_left', 'deMatos_polar._right', 'S.Or.-S.Olf._right', 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right', 'LARGE_CINGULATE._left', 'S.T.i.-S.O.T.lat._left', 'S.T.i.-S.T.s.-S.T.pol._right', 'S.C.-S.Po.C._left', 'S.F.median-S.F.pol.tr.-S.F.sup._right', 'S.T.s._right', 'S.F.int.-S.R._left', 'fronto-parietal_medial_face._left', 'Sc.Cal.-S.Li._right', 'S.s.P.-S.Pa.int._left', 'F.C.L.p.-S.GSM._left', 'S.s.P.-S.Pa.int._right', 'S.Pe.C._right', 'S.Po.C._right', 'LARGE_CINGULATE._right', 'F.I.P.-F.I.P.Po.C.inf._right', 'F.Coll.-S.Rh._right', 'F.C.L.p.-S.GSM._right', 'S.T.s._left', 'S.Or._right', 'S.F.inf.-BROCA-S.Pe.C.inf._right', 'S.Or._left', 'F.C.M.post.-S.p.C._right', 'S.T.i.-S.O.T.lat._right', 'CINGULATE._left', 'deMatos_polar._left', 'S.C.-S.Po.C._right', 'S.C.-sylv._left']
# Sulci grouped by regions:
# S.T.s.-S.GSM._left: ['S.T.s._left']
# S.F.int.-F.C.M.ant._right: ['S.F.int._right', 'F.C.M.ant._right', 'S.R.sup._right']
# Sc.Cal.-S.Li._left: ['F.Cal.ant.-Sc.Cal._left', 'S.O.p._left']
# F.I.P.-F.I.P.Po.C.inf._left: ['F.I.P._left', 'F.I.P.Po.C.inf._left']
# S.F.inter.-S.F.sup._right: ['S.F.sup._right', 'S.F.inter._right']
# S.Or.-S.Olf._left: ['S.Olf._left', 'S.Or._left']
# Lobule_parietal_sup._left: ['S.Po.C.sup._left', 'S.Pa.sup._left', 'F.I.P._left']
# OCCIPITAL_right: ['OCCIPITAL_right']
# S.Po.C._left: ['F.C.L.r.retroC.tr._left', 'S.Po.C.sup._left', 'F.I.P.Po.C.inf._left']
# S.F.marginal-S.F.inf.ant._left: ['S.F.marginal._left', 'S.F.orbitaire._left']
# S.F.marginal-S.F.inf.ant._right: ['S.F.orbitaire._right', 'S.F.marginal._right']
# F.P.O.-S.Cu.-Sc.Cal._left: ['F.Cal.ant.-Sc.Cal._left', 'F.P.O._left', 'S.Cu._left', 'S.O.p._left', 'S.Pa.t._left']
# S.T.s.br._right: ['F.I.P.r.int.1_right', 'S.T.s.ter.asc.ant._right', 'S.T.s.ter.asc.post._right', 'F.I.P.r.int.2_right']
# S.F.int.-S.R._right: ['S.R.inf._right', 'S.F.int._right', 'S.R.sup._right']
# S.T.s.-S.GSM._right: ['S.T.s._right']
# S.Pe.C._left: ['S.Pe.C.marginal._left', 'S.Pe.C.inter._left', 'S.Pe.C.median._left', 'S.Pe.C.inf._left', 'S.Pe.C.sup._left']
# S.C.-S.Pe.C._right: ['S.Pe.C.marginal._right', 'S.Pe.C.median._right', 'S.Pe.C.inter._right', 'S.Pe.C.inf._right', 'S.C._right', 'S.Pe.C.sup._right']
# CINGULATE._right: ['F.C.M.ant._right']
# deMatos._left: ['S.O.T.lat.ant._left', 'S.Rh._left', 'S.O.T.lat.post._left', 'F.Coll._left']
# S.F.int.-F.C.M.ant._left: ['F.C.M.ant._left', 'S.F.int._left', 'S.R.sup._left']
# S.C.-sylv._right: ['S.C._right']
# deMatos._right: ['S.O.T.lat.ant._right', 'F.Coll._right', 'S.Rh._right', 'S.O.T.lat.post._right']
# S.T.s.br._left: ['F.I.P.r.int.1_left', 'S.T.s.ter.asc.ant._left', 'S.T.s.ter.asc.post._left', 'F.I.P.r.int.2_left']
# S.T.i.-S.T.s.-S.T.pol._left: ['S.T.i.post._left', 'S.T.pol._left', 'S.T.s._left', 'S.T.i.ant._left']
# F.I.P._left: ['F.I.P._left']
# S.F.median-S.F.pol.tr.-S.F.sup._left: ['S.F.sup._left', 'S.F.median._left', 'S.F.polaire.tr._left']
# F.P.O.-S.Cu.-Sc.Cal._right: ['F.Cal.ant.-Sc.Cal._right', 'S.Pa.t._right', 'S.O.p._right', 'S.Cu._right', 'F.P.O._right']
# F.C.M.post.-S.p.C._left: ['S.C.LPC._left', 'F.C.M.post._left', 'S.p.C._left']
# fronto-parietal_medial_face._right: ['S.F.int._right', 'S.p.C._right', 'S.Call._right', 'S.R.sup._right', 'F.C.M.post._right', 'S.C.LPC._right', 'S.Pa.int._right', 'F.C.M.ant._right', 'S.s.P._right']
# F.C.L.p.-subsc.-F.C.L.a.-INSULA._left: ['F.C.L.r.sc.post._left', 'F.C.L.a._left', 'F.C.L.r.sc.ant._left', 'F.C.L.p._left', 'INSULA_left']
# S.C.-S.Pe.C._left: ['S.Pe.C.marginal._left', 'S.Pe.C.inter._left', 'S.C._left', 'S.Pe.C.median._left', 'S.Pe.C.inf._left', 'S.Pe.C.sup._left']
# S.F.inter.-S.F.sup._left: ['S.F.sup._left', 'S.F.inter._left']
# Lobule_parietal_sup._right: ['S.Pa.sup._right', 'S.Po.C.sup._right', 'F.I.P._right']
# F.Coll.-S.Rh._left: ['S.Rh._left', 'F.Coll._left']
# S.F.inf.-BROCA-S.Pe.C.inf._left: ['F.C.L.r.asc._left', 'S.F.inf._left', 'F.C.L.r.diag._left', 'S.Pe.C.inf._left', 'F.C.L.r.ant._left']
# F.I.P._right: ['F.I.P._right']
# OCCIPITAL_left: ['OCCIPITAL_left']
# deMatos_polar._right: ['S.O.T.lat.ant._right', 'F.Coll._right', 'S.T.pol._right', 'S.Rh._right', 'S.O.T.lat.post._right']
# S.Or.-S.Olf._right: ['S.Olf._right', 'S.Or._right']
# F.C.L.p.-subsc.-F.C.L.a.-INSULA._right: ['F.C.L.r.sc.ant._right', 'F.C.L.a._right', 'INSULA_right', 'F.C.L.p._right', 'F.C.L.r.sc.post._right']
# LARGE_CINGULATE._left: ['S.C.LPC._left', 'F.C.M.post._left', 'F.C.M.ant._left', 'S.F.int._left', 'S.p.C._left', 'S.R.sup._left']
# S.T.i.-S.O.T.lat._left: ['S.T.i.post._left', 'S.O.T.lat.ant._left', 'S.O.T.lat.post._left', 'S.T.i.ant._left']
# S.T.i.-S.T.s.-S.T.pol._right: ['S.T.pol._right', 'S.T.i.ant._right', 'S.T.s._right', 'S.T.i.post._right']
# S.C.-S.Po.C._left: ['F.C.L.r.retroC.tr._left', 'S.C._left', 'S.Po.C.sup._left', 'F.I.P.Po.C.inf._left']
# S.F.median-S.F.pol.tr.-S.F.sup._right: ['S.F.median._right', 'S.F.polaire.tr._right', 'S.F.sup._right']
# S.T.s._right: ['S.T.s._right']
# S.F.int.-S.R._left: ['S.R.sup._left', 'S.R.inf._left', 'S.F.int._left']
# fronto-parietal_medial_face._left: ['S.Call._left', 'S.R.sup._left', 'S.C.LPC._left', 'F.C.M.post._left', 'F.C.M.ant._left', 'S.F.int._left', 'S.Pa.int._left', 'S.p.C._left', 'S.s.P._left']
# Sc.Cal.-S.Li._right: ['F.Cal.ant.-Sc.Cal._right', 'S.O.p._right']
# S.s.P.-S.Pa.int._left: ['S.Pa.int._left', 'S.s.P._left']
# F.C.L.p.-S.GSM._left: ['F.C.L.p._left']
# S.s.P.-S.Pa.int._right: ['S.Pa.int._right', 'S.s.P._right']
# S.Pe.C._right: ['S.Pe.C.marginal._right', 'S.Pe.C.median._right', 'S.Pe.C.inter._right', 'S.Pe.C.inf._right', 'S.Pe.C.sup._right']
# S.Po.C._right: ['F.I.P.Po.C.inf._right', 'F.C.L.r.retroC.tr._right', 'S.Po.C.sup._right']
# LARGE_CINGULATE._right: ['S.F.int._right', 'S.p.C._right', 'F.C.M.post._right', 'S.C.LPC._right', 'F.C.M.ant._right', 'S.R.sup._right']
# F.I.P.-F.I.P.Po.C.inf._right: ['F.I.P.Po.C.inf._right', 'F.I.P._right']
# F.Coll.-S.Rh._right: ['F.Coll._right', 'S.Rh._right']
# F.C.L.p.-S.GSM._right: ['F.C.L.p._right']
# S.T.s._left: ['S.T.s._left']
# S.Or._right: ['S.Or._right']
# S.F.inf.-BROCA-S.Pe.C.inf._right: ['F.C.L.r.diag._right', 'S.F.inf._right', 'F.C.L.r.asc._right', 'F.C.L.r.ant._right', 'S.Pe.C.inf._right']
# S.Or._left: ['S.Or._left']
# F.C.M.post.-S.p.C._right: ['S.p.C._right', 'F.C.M.post._right', 'S.C.LPC._right']
# S.T.i.-S.O.T.lat._right: ['S.O.T.lat.ant._right', 'S.O.T.lat.post._right', 'S.T.i.ant._right', 'S.T.i.post._right']
# CINGULATE._left: ['F.C.M.ant._left']
# deMatos_polar._left: ['S.O.T.lat.ant._left', 'S.Rh._left', 'S.T.pol._left', 'S.O.T.lat.post._left', 'F.Coll._left']
# S.C.-S.Po.C._right: ['F.I.P.Po.C.inf._right', 'F.C.L.r.retroC.tr._right', 'S.Po.C.sup._right', 'S.C._right']
# S.C.-sylv._left: ['S.C._left']

# %%
# Statistics on the number of sulci per region
region_counts = {region: len(sulci) for region, sulci in region_dict.items()}

# Plot the number of sulci per region
plt.figure(figsize=(12, 6))

plt.bar(
    [region for region in region_counts.keys() if region.endswith("right")],
    [count for region, count in region_counts.items() if region.endswith("right")],color='lightcoral'
)
plt.xlabel('Regions')
plt.ylabel('Number of Sulci')
plt.title('Number of Sulci per Region')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
def get_gravity_center_coordinates(base_path , sulci):

    
    # Read the sulci tsv
    file_path = os.path.join(base_path, sulci)
    # Get the coordinates of the gravity center

    sulci_df = pd.read_csv(file_path, sep='\s+').loc[:,["valid","gravityCenter_x", "gravityCenter_y", "gravityCenter_z","surface"]]

    # Filter the dataframe to keep only the valid sulci
    sulci_df = sulci_df[sulci_df['valid'] == 1]

    return sulci_df

# %%
#sulci = "morpho_S.Or._left.dat"
sulci= "morpho_S.Pe.C.marginal._left.dat"

df_test = get_gravity_center_coordinates(base_path="/neurospin/dico/data/human/pclean/derivatives/morphologist-2021/morphometry/3.3_base2018/morpho_talairach", sulci=sulci)

print(df_test.columns)
# Out:
# Index(['valid', 'gravityCenter_x', 'gravityCenter_y', 'gravityCenter_z',
#        'surface'],
#       dtype='object')

# %%
sulci = "morpho_S.Or._left.dat"

df_test = get_gravity_center_coordinates(base_path="/neurospin/dico/data/human/utrecht/derivatives/morphologist-2023/morphometry/40wks/morpho_talairach", sulci=sulci)

print(df_test.shape)
# Out:
# (71, 5)

# %%
def get_fused_gravity_center(*dfs):
    """
    Compute the fused gravity center across multiple sulci dataframes,
    fully ignoring subjects that are missing in any given sulcus.

    Each df must contain at least the columns:
      - "gravityCenter_x", "gravityCenter_y", "gravityCenter_z"
      - "surface"
    The index of each df must be the subject_id (or any unique subject identifier).
    """
    nbr_dfs = len(dfs)
    print(f"Number of dataframes: {nbr_dfs}")
    for df in dfs:
        print(len(df))

    # Build the union of all subject_ids appearing in at least one dataframe
    all_idx = pd.Index([], dtype="object")
    for df in dfs:
        all_idx = all_idx.union(df.index)

    # Prepare Series to accumulate only the “valid” subjects
    total_area = pd.Series(0.0, index=all_idx)
    sum_x      = pd.Series(0.0, index=all_idx)
    sum_y      = pd.Series(0.0, index=all_idx)
    sum_z      = pd.Series(0.0, index=all_idx)

    # For each sulcus dataframe:
    for df in dfs:
        # Reindex so all subjects share the same index; missing subjects become NaN
        s_surf = df["surface"].reindex(all_idx)             # surface values, NaN if subject absent
        s_x    = df["gravityCenter_x"].reindex(all_idx)     # x-coordinate, NaN if absent
        s_y    = df["gravityCenter_y"].reindex(all_idx)     # y-coordinate, NaN if absent
        s_z    = df["gravityCenter_z"].reindex(all_idx)     # z-coordinate, NaN if absent

        # Keep only rows where surface is non-NaN and > 0
        valid_mask = s_surf.notna() & (s_surf > 0)

        # Accumulate surface only for valid subjects
        total_area[valid_mask] += s_surf[valid_mask]

        # Accumulate (coordinate × surface) for each axis, only for valid subjects
        sum_x[valid_mask] += s_x[valid_mask] * s_surf[valid_mask]
        sum_y[valid_mask] += s_y[valid_mask] * s_surf[valid_mask]
        sum_z[valid_mask] += s_z[valid_mask] * s_surf[valid_mask]

    # Compute the fused gravity center by dividing (sum of coord×surface) by (sum of surfaces)
    fused_x = sum_x.copy()
    fused_y = sum_y.copy()
    fused_z = sum_z.copy()

    # Only divide where total_area is non-zero; otherwise keep NaN (no valid sulci for that subject)
    non_zero = total_area != 0.0
    fused_x[non_zero] = sum_x[non_zero] / total_area[non_zero]
    fused_y[non_zero] = sum_y[non_zero] / total_area[non_zero]
    fused_z[non_zero] = sum_z[non_zero] / total_area[non_zero]

    # Where total_area == 0, leave fused coordinates as NaN
    fused_x[~non_zero] = float("nan")
    fused_y[~non_zero] = float("nan")
    fused_z[~non_zero] = float("nan")

    return pd.DataFrame({
        "gravityCenter_x": fused_x,
        "gravityCenter_y": fused_y,
        "gravityCenter_z": fused_z
    })

# %%
# Example usage of get_fused_gravity_center
sulci1 = "morpho_S.R.sup._left.dat"
sulci2 = "morpho_S.F.int._left.dat"
df1 = get_gravity_center_coordinates(base_path="/neurospin/dico/data/human/utrecht/derivatives/morphologist-2023/morphometry/40wks/morpho_talairach", sulci=sulci1)
df2 = get_gravity_center_coordinates(base_path="/neurospin/dico/data/human/utrecht/derivatives/morphologist-2023/morphometry/40wks/morpho_talairach", sulci=sulci2)
fused_df = get_fused_gravity_center(df1, df2)
print(fused_df)
# Out:
# Number of dataframes: 2
# 71
# 71
#     gravityCenter_x  gravityCenter_y  gravityCenter_z
# 0          7.767363       -18.489293       -37.844542
# 1          7.477038       -22.391634       -39.556036
# 2          6.292470       -30.251285       -17.887410
# 3          4.324983       -31.884146       -22.297820
# 4          7.886628       -26.428940       -27.510925
# ..              ...              ...              ...
# 66         6.787274       -45.860301       -11.762233
# 67         8.181223       -26.151312       -29.921587
# 68         8.160253       -40.209144        -8.202277
# 69         4.800876       -33.706150       -25.722477
# 70         6.817900       -36.221700       -25.344695
#
# [71 rows x 3 columns]

# %%
def compute_gravity_center_coordinates_shift(region):

    """
    Compute the shift of the gravity center coordinates between babies and adults for a given sulcus
    """

    # Get the coordinates of the gravity center for babies
    base_path_babies = "/neurospin/dico/data/human/dHCP/derivatives/release1/morphometry/morpho_talairach"


    # Get the coordinates of the gravity center for adults
    base_path_preterms = "/neurospin/dico/data/human/utrecht/derivatives/morphologist-2023/morphometry/40wks/morpho_talairach"


    # Recalibrate the gravity center for the SR_sup sulcus and the SF_int sulcus in the case of adults
    dfs_adults= []
    dfs_preterms = []
    for sulci in region_dict[region]:
        sulci = "morpho_" + sulci + ".dat"
        df_adults = get_gravity_center_coordinates(base_path_babies, sulci)
        dfs_adults.append(df_adults)
        df_preterms = get_gravity_center_coordinates(base_path_preterms, sulci)
        dfs_preterms.append(df_preterms)
    

    fused_df_preterms = get_fused_gravity_center(*dfs_preterms)
    fused_df_adults = get_fused_gravity_center(*dfs_adults)


    # Create a dataframe with the coordinates shift and the distance between the two gravity centers

    mean_adults = fused_df_adults.mean()
    mean_preterms = fused_df_preterms.mean()

    shift_x = mean_preterms["gravityCenter_x"] - mean_adults["gravityCenter_x"]
    shift_y = mean_preterms["gravityCenter_y"] - mean_adults["gravityCenter_y"]
    shift_z = mean_preterms["gravityCenter_z"] - mean_adults["gravityCenter_z"]
    distance = (shift_x**2 + shift_y**2 + shift_z**2)**0.5

    std_adults = fused_df_adults.std()
    std_preterms = fused_df_preterms.std()

    

    df_shift_sulcus= pd.DataFrame([{
        "region": region,
        "shift_x": shift_x,
        "shift_y": shift_y,
        "shift_z": shift_z,
        "distance": distance,
        "nbr_preterms": fused_df_preterms.shape[0],
        "nbr_adults": fused_df_adults.shape[0],
        "std_adults_x": std_adults["gravityCenter_x"],
        "std_adults__y": std_adults["gravityCenter_y"],
        "std_adults_z": std_adults["gravityCenter_z"],
        "std_preterms_x": std_preterms["gravityCenter_x"],
        "std_preterms_y": std_preterms["gravityCenter_y"],
        "std_prterms_z": std_preterms["gravityCenter_z"],

    }])


    return df_shift_sulcus

# %%
# Test the function
region = "fronto-parietal_medial_face._right"
df_test = compute_gravity_center_coordinates_shift(region)
print(df_test)
# Out:
# Number of dataframes: 9
# 71
# 68
# 66
# 71
# 71
# 64
# 71
# 71
# 71
# Number of dataframes: 9
# 40
# 37
# 40
# 0
# 40
# 15
# 37
# 40
# 40
#                                region   shift_x   shift_y   shift_z  distance  \
# 0  fronto-parietal_medial_face._right -0.367327 -1.016047 -2.947085  3.138884
#
#    nbr_preterms  nbr_babies  std_babies_x  std_babies_y  std_babies_z  \
# 0            71          40      0.728449      4.116951      2.841481
#
#    std_adults_x  std_adults_y  std_adults_z
# 0      1.479491      6.946216      3.447556

# %%
def compute_all_gravity_center_shifts():

    # Get all the .dat files
    regions = list(region_dict.keys())

    # Create an empty list
    all_shifts = []

    for region in regions:
        print(f"Processing region: {region}")
        df_shift = compute_gravity_center_coordinates_shift(region)
        all_shifts.append(df_shift)

    df_all_shifts = pd.concat(all_shifts, ignore_index=True)

    # Save the dataframe to a csv file
    df_all_shifts.to_csv("all_regions_gravity_center_shifts_utrecht_dHCP.csv", index=False)

    # Stats on the distance
    df_summary = df_all_shifts.groupby("region")["shift_x"].mean().sort_values(ascending=False)
    print(df_summary.head(10))

# %%
compute_all_gravity_center_shifts()
# Out:
# Processing region: F.C.M.post.-S.p.C._left
# Number of dataframes: 3
# 68
# 71
# 70
# Number of dataframes: 3
# 28
# 40
# 38
# Processing region: S.C.-sylv._left
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.T.s.br._left
# Number of dataframes: 4
# 64
# 71
# 71
# 61
# Number of dataframes: 4
# 35
# 40
# 40
# 34
# Processing region: S.F.int.-F.C.M.ant._left
# Number of dataframes: 3
# 71
# 71
# 71
# Number of dataframes: 3
# 40
# 40
# 0
# Processing region: S.Or.-S.Olf._right
# Number of dataframes: 2
# 71
# 71
# Number of dataframes: 2
# 40
# 40
# Processing region: F.I.P._left
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.C.-S.Pe.C._left
# Number of dataframes: 6
# 70
# 71
# 71
# 71
# 71
# 71
# Number of dataframes: 6
# 30
# 40
# 40
# 34
# 40
# 35
# Processing region: F.Coll.-S.Rh._right
# Number of dataframes: 2
# 71
# 66
# Number of dataframes: 2
# 40
# 36
# Processing region: F.C.M.post.-S.p.C._right
# Number of dataframes: 3
# 68
# 71
# 64
# Number of dataframes: 3
# 37
# 40
# 15
# Processing region: deMatos._right
# Number of dataframes: 4
# 71
# 71
# 66
# 71
# Number of dataframes: 4
# 40
# 40
# 36
# 40
# Processing region: fronto-parietal_medial_face._right
# Number of dataframes: 9
# 71
# 68
# 66
# 71
# 71
# 64
# 71
# 71
# 71
# Number of dataframes: 9
# 40
# 37
# 40
# 0
# 40
# 15
# 37
# 40
# 40
# Processing region: S.F.int.-S.R._right
# Number of dataframes: 3
# 33
# 71
# 71
# Number of dataframes: 3
# 39
# 40
# 0
# Processing region: F.C.L.p.-S.GSM._left
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: CINGULATE._right
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: F.I.P.-F.I.P.Po.C.inf._left
# Number of dataframes: 2
# 71
# 71
# Number of dataframes: 2
# 40
# 40
# Processing region: S.T.s._right
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: F.C.L.p.-S.GSM._right
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: Sc.Cal.-S.Li._left
# Number of dataframes: 2
# 71
# 48
# Number of dataframes: 2
# 40
# 37
# Processing region: OCCIPITAL_left
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.Po.C._right
# Number of dataframes: 3
# 71
# 67
# 71
# Number of dataframes: 3
# 40
# 39
# 40
# Processing region: S.F.inter.-S.F.sup._left
# Number of dataframes: 2
# 71
# 71
# Number of dataframes: 2
# 40
# 40
# Processing region: S.s.P.-S.Pa.int._right
# Number of dataframes: 2
# 71
# 71
# Number of dataframes: 2
# 37
# 40
# Processing region: S.s.P.-S.Pa.int._left
# Number of dataframes: 2
# 69
# 71
# Number of dataframes: 2
# 40
# 40
# Processing region: F.I.P._right
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.Or._right
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.F.inf.-BROCA-S.Pe.C.inf._left
# Number of dataframes: 5
# 67
# 71
# 70
# 71
# 71
# Number of dataframes: 5
# 40
# 40
# 23
# 40
# 39
# Processing region: S.Po.C._left
# Number of dataframes: 3
# 66
# 71
# 71
# Number of dataframes: 3
# 40
# 40
# 40
# Processing region: F.I.P.-F.I.P.Po.C.inf._right
# Number of dataframes: 2
# 71
# 71
# Number of dataframes: 2
# 40
# 40
# Processing region: S.F.median-S.F.pol.tr.-S.F.sup._left
# Number of dataframes: 3
# 71
# 52
# 67
# Number of dataframes: 3
# 40
# 38
# 38
# Processing region: S.C.-S.Po.C._right
# Number of dataframes: 4
# 71
# 67
# 71
# 71
# Number of dataframes: 4
# 40
# 39
# 40
# 40
# Processing region: Sc.Cal.-S.Li._right
# Number of dataframes: 2
# 71
# 52
# Number of dataframes: 2
# 40
# 39
# Processing region: S.T.s._left
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: LARGE_CINGULATE._right
# Number of dataframes: 6
# 71
# 68
# 71
# 64
# 71
# 71
# Number of dataframes: 6
# 40
# 37
# 40
# 15
# 40
# 0
# Processing region: S.T.s.br._right
# Number of dataframes: 4
# 65
# 71
# 71
# 58
# Number of dataframes: 4
# 38
# 39
# 40
# 33
# Processing region: S.Pe.C._left
# Number of dataframes: 5
# 70
# 71
# 71
# 71
# 71
# Number of dataframes: 5
# 30
# 40
# 34
# 40
# 35
# Processing region: S.T.i.-S.O.T.lat._left
# Number of dataframes: 4
# 71
# 71
# 70
# 71
# Number of dataframes: 4
# 40
# 40
# 40
# 40
# Processing region: Lobule_parietal_sup._left
# Number of dataframes: 3
# 71
# 67
# 71
# Number of dataframes: 3
# 40
# 34
# 40
# Processing region: F.C.L.p.-subsc.-F.C.L.a.-INSULA._right
# Number of dataframes: 5
# 3
# 70
# 71
# 71
# 9
# Number of dataframes: 5
# 15
# 39
# 40
# 40
# 36
# Processing region: S.F.median-S.F.pol.tr.-S.F.sup._right
# Number of dataframes: 3
# 54
# 70
# 71
# Number of dataframes: 3
# 40
# 40
# 40
# Processing region: S.T.s.-S.GSM._right
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.Or._left
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: F.C.L.p.-subsc.-F.C.L.a.-INSULA._left
# Number of dataframes: 5
# 34
# 70
# 9
# 71
# 71
# Number of dataframes: 5
# 33
# 37
# 6
# 40
# 40
# Processing region: S.T.i.-S.T.s.-S.T.pol._left
# Number of dataframes: 4
# 71
# 71
# 71
# 71
# Number of dataframes: 4
# 40
# 37
# 40
# 40
# Processing region: fronto-parietal_medial_face._left
# Number of dataframes: 9
# 64
# 71
# 68
# 71
# 71
# 71
# 69
# 70
# 71
# Number of dataframes: 9
# 40
# 0
# 28
# 40
# 40
# 40
# 40
# 38
# 40
# Processing region: OCCIPITAL_right
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: F.P.O.-S.Cu.-Sc.Cal._right
# Number of dataframes: 5
# 71
# 63
# 52
# 71
# 71
# Number of dataframes: 5
# 40
# 37
# 39
# 40
# 40
# Processing region: S.Pe.C._right
# Number of dataframes: 5
# 70
# 69
# 71
# 70
# 71
# Number of dataframes: 5
# 35
# 37
# 40
# 39
# 37
# Processing region: F.Coll.-S.Rh._left
# Number of dataframes: 2
# 69
# 71
# Number of dataframes: 2
# 39
# 40
# Processing region: S.F.marginal-S.F.inf.ant._right
# Number of dataframes: 2
# 71
# 71
# Number of dataframes: 2
# 38
# 39
# Processing region: S.C.-sylv._right
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.F.inter.-S.F.sup._right
# Number of dataframes: 2
# 71
# 71
# Number of dataframes: 2
# 40
# 40
# Processing region: S.F.inf.-BROCA-S.Pe.C.inf._right
# Number of dataframes: 5
# 69
# 71
# 68
# 70
# 70
# Number of dataframes: 5
# 29
# 40
# 40
# 35
# 39
# Processing region: S.T.i.-S.O.T.lat._right
# Number of dataframes: 4
# 71
# 71
# 71
# 71
# Number of dataframes: 4
# 40
# 40
# 40
# 40
# Processing region: S.F.marginal-S.F.inf.ant._left
# Number of dataframes: 2
# 70
# 69
# Number of dataframes: 2
# 38
# 38
# Processing region: S.F.int.-S.R._left
# Number of dataframes: 3
# 71
# 44
# 71
# Number of dataframes: 3
# 0
# 37
# 40
# Processing region: deMatos_polar._right
# Number of dataframes: 5
# 71
# 71
# 69
# 66
# 71
# Number of dataframes: 5
# 40
# 40
# 37
# 36
# 40
# Processing region: LARGE_CINGULATE._left
# Number of dataframes: 6
# 68
# 71
# 71
# 71
# 70
# 71
# Number of dataframes: 6
# 28
# 40
# 40
# 40
# 38
# 0
# Processing region: S.Or.-S.Olf._left
# Number of dataframes: 2
# 71
# 71
# Number of dataframes: 2
# 40
# 40
# Processing region: S.F.int.-F.C.M.ant._right
# Number of dataframes: 3
# 71
# 71
# 71
# Number of dataframes: 3
# 40
# 40
# 0
# Processing region: Lobule_parietal_sup._right
# Number of dataframes: 3
# 63
# 71
# 71
# Number of dataframes: 3
# 35
# 40
# 40
# Processing region: S.T.i.-S.T.s.-S.T.pol._right
# Number of dataframes: 4
# 69
# 71
# 71
# 71
# Number of dataframes: 4
# 37
# 40
# 40
# 40
# Processing region: CINGULATE._left
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.T.s.-S.GSM._left
# Number of dataframes: 1
# 71
# Number of dataframes: 1
# 40
# Processing region: S.C.-S.Pe.C._right
# Number of dataframes: 6
# 70
# 69
# 71
# 70
# 71
# 71
# Number of dataframes: 6
# 35
# 37
# 40
# 39
# 40
# 37
# Processing region: S.C.-S.Po.C._left
# Number of dataframes: 4
# 66
# 71
# 71
# 71
# Number of dataframes: 4
# 40
# 40
# 40
# 40
# Processing region: F.P.O.-S.Cu.-Sc.Cal._left
# Number of dataframes: 5
# 71
# 71
# 71
# 48
# 64
# Number of dataframes: 5
# 40
# 40
# 40
# 37
# 29
# Processing region: deMatos_polar._left
# Number of dataframes: 5
# 71
# 69
# 71
# 70
# 71
# Number of dataframes: 5
# 40
# 39
# 37
# 40
# 40
# Processing region: deMatos._left
# Number of dataframes: 4
# 71
# 69
# 70
# 71
# Number of dataframes: 4
# 40
# 39
# 40
# 40
# region
# deMatos._right                  4.814319
# F.Coll.-S.Rh._right             4.038537
# deMatos_polar._right            3.563068
# S.T.s.br._right                 3.421500
# S.Or.-S.Olf._left               3.316553
# S.T.i.-S.T.s.-S.T.pol._right    3.051162
# S.F.inter.-S.F.sup._left        2.858578
# S.T.i.-S.O.T.lat._right         2.824220
# Sc.Cal.-S.Li._right             2.493385
# S.Or._left                      2.467569
# Name: shift_x, dtype: float64

# %%
import seaborn as sns
# Sort the dataframe by distance
df_all_shifts_sorted = pd.read_csv("/neurospin/dico/rmenasria/Runs/03_main/Program/2025_rmenasria_prematurity/notebooks/racim/all_regions_gravity_center_shifts_utrecht_dHCP.csv").sort_values(by="distance", ascending=False)
df_left_sulci = df_all_shifts_sorted[df_all_shifts_sorted["region"].str.contains("_left")]

plt.figure(figsize=(12, 8))
sns.barplot(data=df_left_sulci ,x="distance", y="region", palette="viridis")
plt.xlabel("Shift")
plt.ylabel("Sulci")
plt.title("Average shift of the gravity center distance between preterms and full terms")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1545282/2579884694.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_left_sulci ,x="distance", y="region", palette="viridis")

# %%
df_all_shifts_sorted = pd.read_csv("/neurospin/dico/rmenasria/Runs/03_main/Program/2025_rmenasria_prematurity/notebooks/racim/all_regions_gravity_center_shifts_utrecht_dHCP.csv").sort_values(by="shift_x", ascending=False)
df_left_sulci = df_all_shifts_sorted[df_all_shifts_sorted["region"].str.contains("_left")]



plt.figure(figsize=(12, 8))
sns.barplot(data=df_left_sulci, x="shift_x", y="region", palette="viridis")
plt.xlabel("Shift")
plt.ylabel("Sulci")
plt.title("Average shift of the gravity x coordinate between preterms and full terms")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1545282/326295564.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_left_sulci, x="shift_x", y="region", palette="viridis")

# %%
df_all_shifts_sorted = pd.read_csv("/neurospin/dico/rmenasria/Runs/03_main/Program/2025_rmenasria_prematurity/notebooks/racim/all_regions_gravity_center_shifts_utrecht_dHCP.csv").sort_values(by="shift_y", ascending=False)
df_left_sulci = df_all_shifts_sorted[df_all_shifts_sorted["region"].str.contains("_left")]


plt.figure(figsize=(12, 8))
sns.barplot(data=df_left_sulci, x="shift_y", y="region", palette="viridis")
plt.xlabel("Shift")
plt.ylabel("Sulci")
plt.title("Average shift of the gravity y coordinate between preterms and full terms")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1545282/3368264308.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_left_sulci, x="shift_y", y="region", palette="viridis")

# %%
df_all_shifts_sorted = pd.read_csv("/neurospin/dico/rmenasria/Runs/03_main/Program/2025_rmenasria_prematurity/notebooks/racim/all_regions_gravity_center_shifts_utrecht_dHCP.csv").sort_values(by="shift_z", ascending=False)
df_left_sulci = df_all_shifts_sorted[df_all_shifts_sorted["region"].str.contains("_left")]

plt.figure(figsize=(12, 8))
sns.barplot(data=df_left_sulci, x="shift_z", y="region", palette="viridis")
plt.xlabel("Shift")
plt.ylabel("Sulci")
plt.title("Average shift of the gravity z coordinate between preterms and full terms")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1545282/1618422335.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_left_sulci, x="shift_z", y="region", palette="viridis")
